# %% [markdown]
# # Gather NIH RePORTER API Data
# Started 2023-07-27 ZD
#
# This notebook will explore the process of using the NIH RePORTER API (Endpoint: https://api.reporter.nih.gov/v2/projects/search; Docs: https://api.reporter.nih.gov/) to gather grants data. The goal is to build a system that can use the NOFOs (Notice of Funding Opportunity) and/or Awards listed in the Key Programs file in order to get all awards associated with each Key Program. **This notebook will not be used for production processing.**
#
# **Update:** All functionality from this notebook has been copied to `nih_reporter_api.py`, `clean_grants_data.py`, or `main.py`.

# %% [markdown]
# **NOTE**
# From a banner at the top of https://api.reporter.nih.gov/:
#
# `HHS has issued a directive for OPDIVS to implement standardized terminology in funding opportunities. As part of this initiative, the Office of Extramural Research (OER) at NIH is currently in the process of updating funding opportunity templates, websites, and other relevant resources to align with the revised terminology. This information can be found in the OER Policy Announcement 2023-02.`
#
# `Effective August 31, 2023, there will be a change in the way FOA Numbers are handled through the API Service. Moving forward, only the long FOA Number (Full_FOA) will be available, and it will be referred to as the "Opportunity Number." Additionally, the short FOA Number will no longer be supported and will be removed from the API.`

# %%
import pandas as pd
import requests
from time import sleep # for retrying API calls
from math import ceil # for pagination logging

# Method to import from parent directory
import os
import sys
root_dir = os.path.abspath(os.path.join(os.getcwd(), "../"))
sys.path.append(root_dir)

import config

# %%
# Early attempt

# def get_nih_reporter_grants(foa_values, print_meta=False):
#     """Get grants info for provided foa_values"""

#     base_url = "https://api.reporter.nih.gov/v2/projects/search"
#     grants_data = []

#     for foa in foa_values:
#         params = {
#             "criteria": {
#                 "foa": [foa],
#                 "exclude_subprojects": True,
#                 "agencies": ["NCI"]
#             },
#             "limit": 500,
#             "sort_field":"ApplId",
#             "sort_order":"asc",
#         }

#         response = requests.post(base_url, 
#                                  json=params, 
#                                  headers={
#                                      "accept": "application/json", 
#                                      "Content-Type": "application/json"})

#         if response.status_code == 200:
#             grants = response.json()
#             grants_data.extend(grants['results'])
#         else:
#             print(f"Error occurred while fetching grants for FOA '{foa}': {response.status_code}")

#         if print_meta == True:
#             print(f"Response Metadata:\n {grants['meta']}")

#     return grants_data

# %% [markdown]
# Some troubleshooting findings not shown here that led to the `get_nih_reporter_grants_from_nofo` function:
# * The "include_fields" and "exclude_fields" do not seem to be working as the documentation says they should. They give unpredictable and unintuitive results, so they wer removed from the API call parameters. This means that we'll gather more info than necessary and then remove unneeded columns later. Not performant, but may be negligible at our low scale.
# * The `offset` and `limit` parameters need to be used together in a loop to create manual pagination in order to capture all results. The max limit on records within a response is 500, but some NOFOs have 1,000s of records. Without manual pagination, only the first 500 records will be gathered before moving on to the next NOFO.
# * Using sort_field with `ProjectNum` throws errors. Stick with default `ApplId`, even though that's less relevant to us. Maybe not all records have ProjectNums.
# * If a blank value is input into the NOFO, it tries to return ~150,000 records until the max `offset` value of 14,900 is reached.

# %%
# OBSOLETE, REPLACED LATER BY get_nih_reporter_grants
def get_nih_reporter_grants_from_nofo(nofo_values:str, print_meta=False):
    """Get grants info for provided NOFOs.
    
    :param nofo_values: string of Notice of Funding Opportunities (NOFOs) 
        separated by semicolon. 

    :param print_meta: boolean indicator. If True, print API gathering process
        results to console"""

    base_url = "https://api.reporter.nih.gov/v2/projects/search"
    grants_data = []

    for nofo in nofo_values:
        # Check for blank NOFO values
        if not nofo:
            print(f"Blank NOFO value encountered. Skipping.")
            continue

        # Set default values for params not likley to change
        LIMIT = 500
        MAX_ATTEMPTS = 5
        RETRY_TIME = 2

        # Set starting value for counters
        offset = 0
        page = 0
        attempts = 0

        # RePORTER API sets a max limit of 500 records per call.
        # Keep looping each call in "pages" until the number of records 
        # gathered reaches the total number of records available. 
        
        # Set a cap on the number of attempts at a failed call before 
        # moving on to the next NOFO.
        while attempts < MAX_ATTEMPTS:
            # Set parameters for API call
            params = {
                "criteria": {
                    "foa": [nofo],
                    "exclude_subprojects": True,
                    "agencies": ["NCI"]
                },
                "limit": LIMIT,
                "offset": offset,
                "sort_field": "FiscalYear",
                "sort_order": "desc",
            }

            try: 
                # Define response details
                response = requests.post(base_url, 
                                        json=params, 
                                        headers={
                                            "accept": "application/json", 
                                            "Content-Type": "application/json"})

                # If response is good, get results
                if response.status_code == 200:
                    grants = response.json()
                    # Add API source indicator
                    for grant in grants['results']:
                        grant['api_source_search'] = f"NOFO_search: {nofo}"
                    # Add grants to running list
                    grants_data.extend(grants['results'])

                    # Increase offset by limit to get next "page"
                    total_records = grants['meta']['total']
                    offset = offset + LIMIT
                    page = page + 1

                    # Print paginated partial optional metadata
                    # Consider replacing this with proper logging
                    if print_meta == True:
                        total_pages = max(ceil(total_records/LIMIT),1)
                        print(f"NOFO Results: {nofo} ({page}/{total_pages}): "
                              f"{grants['meta']}")

                    # Stop looping if offset has reached total record count
                    if offset >= total_records:
                        break

                # Handle 500 errors by retrying after 2 second delay
                elif response.status_code == 500:
                    attempts = attempts + 1
                    print(f"Received a 500 error for NOFO '{nofo}'. "
                          f"Retrying after {RETRY_TIME} seconds. "
                          f"Attempt {attempts}/{MAX_ATTEMPTS}")
                    sleep(RETRY_TIME)
                else:
                    print(f"Error occurred while fetching grants for NOFO "
                          f"'{nofo}': {response.status_code}")
                    break

            except requests.exceptions.RequestException as e:
                print(f"An error occurred while making the API call for NOFO "
                      f"'{nofo}': {e}")
                break

    return grants_data

# %%
# Copy/Pase the All of Us Qualtrics NOFO cell, and convert string to list
allOfUs_string = "HG21-041;LM21-002;MH22-200;OD21-144;OD22-150;OD22-153;OTA17-002;OTA18-001;OTA19-002;OTA19-003;OTA19-004;OTA20-001;OTA20-009;OTA22-006;OTA23-001;OTA23-003;A17-446;;PA18-91;PA20-145;PA20-185;PA20-272;PAR20-150;PM23-001;PM23-002;RM21-002;RM21-003;RM21-005;RM21-006;RM21-016;SM18-009;SM21-007;SP20-002"
allOfUs_listed = allOfUs_string.split(';')

# Use complicated long list of All of Us NOFOs as NOFO search
nofo_values = allOfUs_listed

# Simple NOFO for NOFO search
#nofo_values = ['RFA-CA-21-052']

# Run grants_data
grants_data = get_nih_reporter_grants_from_nofo(nofo_values, print_meta=True)

print(f"Total records gathered: {len(grants_data)}")
# Out:
# NOFO Results: HG21-041 (1/1): {'search_id': 'PmNufeXFdEeemdS9wQYsOA', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/PmNufeXFdEeemdS9wQYsOA/projects'}}
# NOFO Results: LM21-002 (1/1): {'search_id': '9bYF0UqSbk-SD-r7Bb2F6A', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/9bYF0UqSbk-SD-r7Bb2F6A/projects'}}
# NOFO Results: MH22-200 (1/1): {'search_id': '3mKwhA1ol0OwdS-uuL3b4A', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/3mKwhA1ol0OwdS-uuL3b4A/projects'}}
# NOFO Results: OD21-144 (1/1): {'search_id': 'fIEZPTd42USdtTLaHyb-Hw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/fIEZPTd42USdtTLaHyb-Hw/projects'}}
# NOFO Results: OD22-150 (1/1): {'search_id': 'D7-hUg_PBEC71wjCPj0Iuw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/D7-hUg_PBEC71wjCPj0Iuw/projects'}}
# NOFO Results: OD22-153 (1/1): {'search_id': 'a4vd0COYsUadfV6E6xIuQg', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/a4vd0COYsUadfV6E6xIuQg/projects'}}
# NOFO Results: OTA17-002 (1/1): {'search_id': '2ccQmIqYLUCF1RjFpm1VoQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/2ccQmIqYLUCF1RjFpm1VoQ/projects'}}
# NOFO Results: OTA18-001 (1/1): {'search_id': 'Y1u3r5OMmEWPV_jtjEoRCw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/Y1u3r5OMmEWPV_jtjEoRCw/projects'}}
# NOFO Results: OTA19-002 (1/1): {'search_id': 'ES_qoqBIXEKHoDyux-rFdw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/ES_qoqBIXEKHoDyux-rFdw/projects'}}
# NOFO Results: OTA19-003 (1/1): {'search_id': 'KRpTWdX9oEGYkO_S8Py3-g', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/KRpTWdX9oEGYkO_S8Py3-g/projects'}}
# NOFO Results: OTA19-004 (1/1): {'search_id': 'BZKrUiEwP0uIEy0aGPDK5w', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/BZKrUiEwP0uIEy0aGPDK5w/projects'}}
# NOFO Results: OTA20-001 (1/1): {'search_id': 'Ev7WAEgCT0GXw3d4ixBmZA', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/Ev7WAEgCT0GXw3d4ixBmZA/projects'}}
# NOFO Results: OTA20-009 (1/1): {'search_id': 'nH_EwMLRVUm6ePJey7kjWQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/nH_EwMLRVUm6ePJey7kjWQ/projects'}}
# NOFO Results: OTA22-006 (1/1): {'search_id': '1PHgM0qAkUGy-KCFs_QCmQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/1PHgM0qAkUGy-KCFs_QCmQ/projects'}}
# NOFO Results: OTA23-001 (1/1): {'search_id': 'ttFJduMJyUmwAtWx7aLzog', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/ttFJduMJyUmwAtWx7aLzog/projects'}}
# NOFO Results: OTA23-003 (1/1): {'search_id': '7vtW8guNnU25Hg2cX3_-MQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/7vtW8guNnU25Hg2cX3_-MQ/projects'}}
# NOFO Results: A17-446 (1/1): {'search_id': 'Rurtab-ClEGfkobJJTz88Q', 'total': 4, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/Rurtab-ClEGfkobJJTz88Q/projects'}}
# Blank NOFO value encountered. Skipping.
# NOFO Results: PA18-91 (1/1): {'search_id': 'A2Adhex8skqqTTof7vzY_Q', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/A2Adhex8skqqTTof7vzY_Q/projects'}}
# NOFO Results: PA20-145 (1/1): {'search_id': 'TD_yJ5XC4k2ReiDNawiLUQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/TD_yJ5XC4k2ReiDNawiLUQ/projects'}}
# NOFO Results: PA20-185 (1/6): {'search_id': 'UEMt51nbvEW1cX2eeOGT3A', 'total': 2627, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/UEMt51nbvEW1cX2eeOGT3A/projects'}}
# NOFO Results: PA20-185 (2/6): {'search_id': 'BOFIvTwSHUehdOVL1BViBw', 'total': 2627, 'offset': 500, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/BOFIvTwSHUehdOVL1BViBw/projects'}}
# NOFO Results: PA20-185 (3/6): {'search_id': 'YIuc1PUBrkOx503rJJeVfg', 'total': 2627, 'offset': 1000, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/YIuc1PUBrkOx503rJJeVfg/projects'}}
# NOFO Results: PA20-185 (4/6): {'search_id': 'VhEGTG2qok2Aq1t71Qe0TQ', 'total': 2627, 'offset': 1500, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/VhEGTG2qok2Aq1t71Qe0TQ/projects'}}
# NOFO Results: PA20-185 (5/6): {'search_id': 'OkaR2rPjIkO880C8feXG-g', 'total': 2627, 'offset': 2000, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/OkaR2rPjIkO880C8feXG-g/projects'}}
# NOFO Results: PA20-185 (6/6): {'search_id': 'srpMCUoPSEyD0OM3b-Mv3Q', 'total': 2627, 'offset': 2500, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/srpMCUoPSEyD0OM3b-Mv3Q/projects'}}
# NOFO Results: PA20-272 (1/2): {'search_id': 'jIvUv_5oHkm2FEkQL4uOXw', 'total': 543, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/jIvUv_5oHkm2FEkQL4uOXw/projects'}}
# NOFO Results: PA20-272 (2/2): {'search_id': 'hZfJ3ZQmU0uoNc2dtOeFiA', 'total': 543, 'offset': 500, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/hZfJ3ZQmU0uoNc2dtOeFiA/projects'}}
# NOFO Results: PAR20-150 (1/1): {'search_id': 'snD7a3pYQESInVL_W8MgQg', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/snD7a3pYQESInVL_W8MgQg/projects'}}
# NOFO Results: PM23-001 (1/1): {'search_id': '_q4TGml8bEmoxvdempguEQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/_q4TGml8bEmoxvdempguEQ/projects'}}
# NOFO Results: PM23-002 (1/1): {'search_id': 'lS5MQgasmE-wW_q2e-ptHw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/lS5MQgasmE-wW_q2e-ptHw/projects'}}
# NOFO Results: RM21-002 (1/1): {'search_id': 'H-fKDs2v2kqn4K2Y_W01Lw', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/H-fKDs2v2kqn4K2Y_W01Lw/projects'}}
# NOFO Results: RM21-003 (1/1): {'search_id': 'zJr3ATAti0CE1ijTa88hOw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/zJr3ATAti0CE1ijTa88hOw/projects'}}
# NOFO Results: RM21-005 (1/1): {'search_id': 'LCdzlR5_2kC3oSsU3PfMDw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/LCdzlR5_2kC3oSsU3PfMDw/projects'}}
# NOFO Results: RM21-006 (1/1): {'search_id': 'l-RlpyCByUuoiuQLS2lMWA', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/l-RlpyCByUuoiuQLS2lMWA/projects'}}
# NOFO Results: RM21-016 (1/1): {'search_id': 'mVNDYEjPUkC7fEOZBeAOMw', 'total': 8, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/mVNDYEjPUkC7fEOZBeAOMw/projects'}}
# NOFO Results: SM18-009 (1/1): {'search_id': 'PRTGStAuNEuzt2izihVOng', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/PRTGStAuNEuzt2izihVOng/projects'}}
# NOFO Results: SM21-007 (1/1): {'search_id': 'f3BYgoET3kmfrTw5r5Xk_w', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/f3BYgoET3kmfrTw5r5Xk_w/projects'}}
# NOFO Results: SP20-002 (1/1): {'search_id': '_2sR2A9WK0Oxn2-2W_ou7g', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/_2sR2A9WK0Oxn2-2W_ou7g/projects'}}
# Total records gathered: 3186

# %%
# Display first 10 grants
for grant in grants_data[:10]:
    print(grant['project_num'])
# Out:
# 5R21CA238356-02
# 1R21CA238356-01A1
# 5R21CA230879-02
# 1R21CA230879-01
# 5R01CA270483-02
# 1R01CA270483-01
# 5R01CA264984-03
# 5R01CA268597-02
# 5R01CA259469-02
# 5R01CA251545-03

# %%
# Display all data gathered for first grant
grants_data[0]
# Out:
# {'appl_id': 10064138,
#  'subproject_id': None,
#  'fiscal_year': 2021,
#  'org_name': 'EMORY UNIVERSITY',
#  'org_city': 'ATLANTA',
#  'org_state': 'GA',
#  'org_state_name': None,
#  'dept_type': 'PUBLIC HEALTH & PREV MEDICINE',
#  'project_num': '5R21CA238356-02',
#  'project_serial_num': 'CA238356',
#  'org_country': 'UNITED STATES',
#  'organization': {'org_name': 'EMORY UNIVERSITY',
#   'city': None,
#   'country': None,
#   'org_city': 'ATLANTA',
#   'org_country': 'UNITED STATES',
#   'org_state': 'GA',
#   'org_state_name': None,
#   'dept_type': 'PUBLIC HEALTH & PREV MEDICINE',
#   'fips_country_code': None,
#   'org_duns': ['066469933'],
#   'org_ueis': ['S352L5PJLMP8'],
#   'primary_duns': '066469933',
#   'primary_uei': 'S352L5PJLMP8',
#   'org_fips': 'US',
#   'org_ipf_code': '2384501',
#   'org_zipcode': '303221007',
#   'external_org_id': 2384501},
#  'award_type': '5',
#  'activity_code': 'R21',
#  'award_amount': 216667,
#  'is_active': False,
#  'is_territory': False,
#  'project_num_split': {'appl_type_code': '5',
#   'activity_code': 'R21',
#   'ic_code': 'CA',
#   'serial_num': '238356',
#   'support_year': '02',
#   'full_support_year': '02',
#   'suffix_code': ''},
#  'principal_investigators': [{'profile_id': 1873123,
#    'first_name': 'COLLEEN',
#    'middle_name': 'M',
#    'last_name': 'MC BRIDE',
#    'is_contact_pi': True,
#    'full_name': 'COLLEEN M MC BRIDE',
#    'title': 'GRACE CRUM ROLLINS PROFESSOR AND CHAIR',
#    'email': None}],
#  'contact_pi_name': 'MC BRIDE, COLLEEN M',
#  'program_officers': [{'first_name': 'VERONICA',
#    'middle_name': '',
#    'last_name': 'CHOLLETTE',
#    'full_name': 'VERONICA  CHOLLETTE',
#    'email': None}],
#  'agency_ic_admin': {'code': 'CA',
#   'abbreviation': 'NCI',
#   'name': 'National Cancer Institute'},
#  'agency_ic_fundings': [{'fy': 2021,
#    'code': 'CA',
#    'name': 'National Cancer Institute',
#    'abbreviation': 'NCI',
#    'total_cost': 216667.0}],
#  'cong_dist': 'GA-05',
#  'spending_categories': [31,
#   120,
#   132,
#   176,
#   275,
#   276,
#   3641,
#   298,
#   3584,
#   564,
#   701,
#   729,
#   3724],
#  'project_start_date': '2019-12-03T12:12:00Z',
#  'project_end_date': '2022-11-30T12:11:00Z',
#  'organization_type': {'name': 'SCHOOLS OF PUBLIC HEALTH',
#   'code': '10',
#   'is_other': False},
#  'all_text': None,
#  'foa': 'PA17-446',
#  'full_foa': 'PA-17-446',
#  'full_study_section': {'srg_code': 'ZRG1',
#   'srg_flex': '',
#   'sra_designator_code': 'SEIR',
#   'sra_flex_code': 'B',
#   'group_code': '80',
#   'name': 'Special Emphasis Panel[ZRG1-SEIR-B(80)]'},
#  'award_notice_date': '2020-11-24T12:11:00Z',
#  'is_new': False,
#  'mechanism_code_dc': 'RP',
#  'core_project_num': 'R21CA238356',
#  'terms': '<Adoption><Awareness><malignant breast neoplasm><Breast Cancer><malignant breast tumor><Malignant Neoplasms><Cancers><Malignant Tumor><malignancy><neoplasm/cancer><Communities><Conflict (Psychology)><Conflict><Family><Focus Groups><Future><Genetic Counseling><Goals><Grant><Hand><Healthcare Systems><Health Care Systems><Health Personnel><Health Care Providers><Healthcare Providers><Healthcare worker><health care personnel><health care worker><health provider><health workforce><healthcare personnel><medical personnel><treatment provider><Health Services Research><Health Services Evaluation><Medical Care Research><services research><Heredity><Light><Photoradiation><Methods><Minority Groups><Minority People><Minority Population><Mutation><Genetic Alteration><Genetic Change><Genetic defect><genome mutation><Hereditary Neoplastic Syndromes><Familiar Neoplastic Syndrome><Hereditary Cancer Syndromes><Pilot Projects><pilot study><Recommendation><Research><Resources><Research Resources><Risk><medical specialties><Specialty><Surveys><Survey Instrument><Syndrome><Translations><Woman><Privacy><symposium><conference><convention><summit><symposia><Healthcare><health care><Caring><Procedures><Area><Evaluation><Screening procedure><screening tools><Training><insight><Individual><Trust><African><Policy Maker><Logistics><Policies><uptake><Screening for Ovarian Cancer><ovarian cancer detection><ovarian cancer early detection><ovarian cancer early screening><Published Comment><Comment><Commentary><Editorial Comment><Viewpoint><Genetic Predisposition><Genetic Susceptibility><Inherited Predisposition><Inherited Susceptibility><genetic etiology><genetic mechanism of disease><genetic vulnerability><genetically predisposed><Genetic Predisposition to Disease><Exposure to><tool><Consensus><Knowledge><Hereditary><Inherited><Clinic><Protocol><Protocols documentation><psychosocial><interest><Genetic Services><Familial Breast and Ovarian Cancer Syndrome><Hereditary Breast and Ovarian Cancer><Hereditary Breast and Ovarian Cancer Syndrome><novel><Participant><Prevention Research><Agreement><Basic Research><Basic Science><Prevention><cancer genetics><social><Common Good><Provider><Malignant Ovarian Neoplasm><Malignant Ovarian Tumor><Malignant Tumor of the Ovary><Ovary Cancer><ovarian cancer><Malignant neoplasm of ovary><Address><Public Health Applications><Public Health Applications Research><Genetic Risk><Screening Result><Underrepresented Minority><Underrepresented Ethnic Minority><under-representation of minorities><under-represented minority><underrepresentation of minorities><Process><follow-up><Active Follow-up><active followup><follow up><followed up><followup><Development><developmental><Output><cost><Outcome><Population><high risk><population based><primary outcome><deliberative democracy><screening><personalized screening><precision screening><variant of unknown significance><unclassified variant><variant of uncertain clinical significance><variant of uncertain significance><variant of undetermined significance><racial disparity><disparities in race><race disparity><minority communities><recruit><service delivery><genetic testing><gene testing><gene-based testing><treatment research><distrust><testing uptake><service uptake><aggressive breast cancer><black women><black female>',
#  'pref_terms': 'Address;Adoption;African;Agreement;Area;Awareness;Basic Science;Caring;Clinic;Common Good;Communities;Conflict (Psychology);Consensus;Development;Evaluation;Exposure to;Family;Focus Groups;Future;Genetic Counseling;Genetic Predisposition to Disease;Genetic Risk;Genetic Services;Goals;Grant;Hand;Health Personnel;Health Services Research;Healthcare;Healthcare Systems;Hereditary Breast and Ovarian Cancer Syndrome;Hereditary Neoplastic Syndromes;Heredity;Individual;Inherited;Knowledge;Light;Logistics;Malignant Neoplasms;Malignant neoplasm of ovary;Methods;Minority Groups;Mutation;Outcome;Output;Participant;Pilot Projects;Policies;Policy Maker;Population;Prevention;Prevention Research;Privacy;Procedures;Process;Protocols documentation;Provider;Public Health Applications Research;Published Comment;Recommendation;Research;Resources;Risk;Screening Result;Screening for Ovarian Cancer;Screening procedure;Surveys;Syndrome;Training;Translations;Trust;Underrepresented Minority;Woman;aggressive breast cancer;black women;cancer genetics;cost;deliberative democracy;distrust;follow-up;genetic testing;high risk;insight;interest;malignant breast neoplasm;medical specialties;minority communities;novel;personalized screening;population based;primary outcome;psychosocial;racial disparity;recruit;screening;service delivery;service uptake;social;symposium;testing uptake;tool;treatment research;uptake;variant of unknown significance',
#  'abstract_text': 'PROJECT SUMMARY\nSeveral national organizations concur that population screening to identify individuals and\nfamilies at highest risk for inherited cancer syndromes is warranted. Low cost genetic risk\nscreening tools are available for several inherited cancer syndromes including heredity breast\nand ovarian cancer (HBOC). Nonetheless, evidence suggests that early translation efforts to get\nthese cancer genetic services into the hands of underrepresented minority populations are not\novercoming existing disparity propensities. Most research has focused on tweaking existing\nservice delivery strategies (e.g., activated providers, telegenetics), but these efforts have not\nshown consistent improvement in service uptake among those of African ancestry (AAn).\nResearch has yet to enlist communities of AAn to thoughtfully consider whether expanding\nHBOC screening is in the interest of the common good and warranted to redress their poor\ncancer outcomes. Democratic deliberation (DD) approaches can offer a way to engage\ncommunities of AAn to consider whether and how screening for HBOC should be expanded. We\npropose to evaluate the feasibility and quality of the DD process in a region serving large\ncommunities of AAn in south Georgia. The specific aims are: Aim 1: Use DD methods to plan a\ncitizen deliberation conference for south Georgia residents of AAn concerning HBOC population\nscreening and develop the following: participant workbook, expert presentations, output\nevaluation procedures, facilitator training protocols, and recruitment plans. Aim 2: Conduct and\nevaluate a 2-day deliberative conference in Albany, Georgia with 25 participants to: (a) become\naware of different viewpoints surrounding HBOC population screening, (b) support large- and\nsmall-group deliberation on these viewpoints, and (c) reach consensus on what approach for\nHBOC screening among communities of AAn, if any, is in the common good. Primary outcomes\nare quality of the deliberation process as indicated by recorded small-group deliberations, and\nimpacts on participants. Aim 2a: Conduct a 3-month follow-up online deliberation with a larger\npanel, to gain insight into the external validity of the output of the DD conference (acceptability\nof, and agreement with, the consensus reached relating to HBOC population screening in\nGeorgia). Results of this pilot study will inform the development of future larger grant. We plan\nto evaluate DD approaches for HBOC screening across the state of Georgia. The efforts will\ninclude us gaining the input of health care providers and policy makers to consider whether to\nexpand population-based HBOC screening among communities of AAn.',
#  'project_title': 'Evaluating Deliberative Democracy Approaches with Citizens of African Ancestry Regarding Population Screening for Hereditary Cancer Syndromes',
#  'phr_text': 'PROJECT NARRATIVE\nWe propose to develop and evaluate the feasibility and quality of a democratic deliberation (DD) approach for\neliciting informed community perspectives on whether and how screening for hereditary breast and ovarian\ncancer (HBOC) should be expanded in an area serving a large community of African Ancestry (AAn) in south\nGeorgia. Results of this pilot study will inform DDs on HBOC across the state of Georgia, and prepare us in\npursuing future grants that seek the input of health care providers and policy makers to consider ways to\nimplement population-based HBOC screening among communities of AAn.',
#  'spending_categories_desc': "Aging; Breast Cancer; Cancer; Clinical Research; Genetic Testing; Genetics; Health Disparities; Health Services; Minority Health; Ovarian Cancer; Prevention; Rare Diseases; Women's Health",
#  'awd_doc_num': 'RCA238356A',
#  'init_encumbrance_date': '2020-11-24T12:11:17Z',
#  'can_task': ['2021.100'],
#  'special_topic_code': ['CI'],
#  'agency_code': 'NIH',
#  'covid_response': None,
#  'arra_funded': 'N',
#  'budget_start': '2020-12-01T12:12:00Z',
#  'budget_end': '2022-11-30T12:11:00Z',
#  'cfda_code': '393',
#  'funding_mechanism': 'Non-SBIR/STTR',
#  'direct_cost_amt': 144200,
#  'indirect_cost_amt': 72467,
#  'project_detail_url': 'https://reporter.nih.gov/project-details/10064138',
#  'date_added': '2020-12-05T07:12:23Z',
#  'api_source_search': 'NOFO_search: A17-446'}

# %% [markdown]
# ### We've pulled data from the API. Now to determine how to unpack and format it.

# %% [markdown]
# Try to make sense of this JSON response by flattening it into a dataframe

# %%
# Load grants JSON as pandas dataframe
df_grants = pd.DataFrame(grants_data)

# Check that length matches above
print(f"Row count: {len(df_grants)}")

print(f"Matches total grants gathered? {len(df_grants) == len(grants_data)}")

# Display first 5 rows
df_grants.head()
# Out:
# Row count: 3186
# Matches total grants gathered? True
#     appl_id subproject_id  fiscal_year                           org_name  \
# 0  10064138          None         2021                   EMORY UNIVERSITY
# 1   9893342          None         2020                   EMORY UNIVERSITY
# 2   9728901          None         2019  SLOAN-KETTERING INST CAN RESEARCH
# 3   9582452          None         2018  SLOAN-KETTERING INST CAN RESEARCH
# 4  10610465          None         2023         UNIVERSITY OF PENNSYLVANIA
#
#        org_city org_state org_state_name                      dept_type  \
# 0       ATLANTA        GA           None  PUBLIC HEALTH & PREV MEDICINE
# 1       ATLANTA        GA           None  PUBLIC HEALTH & PREV MEDICINE
# 2      NEW YORK        NY           None                           None
# 3      NEW YORK        NY           None                           None
# 4  PHILADELPHIA        PA           None       OTHER HEALTH PROFESSIONS
#
#          project_num project_serial_num  ... arra_funded  \
# 0    5R21CA238356-02           CA238356  ...           N
# 1  1R21CA238356-01A1           CA238356  ...           N
# 2    5R21CA230879-02           CA230879  ...           N
# 3    1R21CA230879-01           CA230879  ...           N
# 4    5R01CA270483-02           CA270483  ...           N
#
#            budget_start            budget_end cfda_code  funding_mechanism  \
# 0  2020-12-01T12:12:00Z  2022-11-30T12:11:00Z       393      Non-SBIR/STTR
# 1  2019-12-03T12:12:00Z  2020-11-30T12:11:00Z       393      Non-SBIR/STTR
# 2  2019-06-01T12:06:00Z  2022-05-31T12:05:00Z       393      Non-SBIR/STTR
# 3  2018-06-20T12:06:00Z  2019-05-31T12:05:00Z       393      Non-SBIR/STTR
# 4  2023-04-01T12:04:00Z  2024-03-31T12:03:00Z       395      Non-SBIR/STTR
#
#    direct_cost_amt  indirect_cost_amt  \
# 0           144200            72467.0
# 1           119912            65411.0
# 2           126585           100762.0
# 3           108750            77974.0
# 4           530940           111689.0
#
#                                   project_detail_url            date_added  \
# 0  https://reporter.nih.gov/project-details/10064138  2020-12-05T07:12:23Z
# 1   https://reporter.nih.gov/project-details/9893342  2019-12-07T07:12:55Z
# 2   https://reporter.nih.gov/project-details/9728901  2019-06-01T07:06:09Z
# 3   https://reporter.nih.gov/project-details/9582452  2018-06-23T07:06:14Z
# 4  https://reporter.nih.gov/project-details/10610465  2023-05-04T04:05:27Z
#
#       api_source_search
# 0  NOFO_search: A17-446
# 1  NOFO_search: A17-446
# 2  NOFO_search: A17-446
# 3  NOFO_search: A17-446
# 4  NOFO_search: PA18-91
#
# [5 rows x 58 columns]

# %%
# Show all top-level columns captured by the dataframe conversion
df_grants.columns.tolist()
# Out:
# ['appl_id',
#  'subproject_id',
#  'fiscal_year',
#  'org_name',
#  'org_city',
#  'org_state',
#  'org_state_name',
#  'dept_type',
#  'project_num',
#  'project_serial_num',
#  'org_country',
#  'organization',
#  'award_type',
#  'activity_code',
#  'award_amount',
#  'is_active',
#  'is_territory',
#  'project_num_split',
#  'principal_investigators',
#  'contact_pi_name',
#  'program_officers',
#  'agency_ic_admin',
#  'agency_ic_fundings',
#  'cong_dist',
#  'spending_categories',
#  'project_start_date',
#  'project_end_date',
#  'organization_type',
#  'all_text',
#  'foa',
#  'full_foa',
#  'full_study_section',
#  'award_notice_date',
#  'is_new',
#  'mechanism_code_dc',
#  'core_project_num',
#  'terms',
#  'pref_terms',
#  'abstract_text',
#  'project_title',
#  'phr_text',
#  'spending_categories_desc',
#  'awd_doc_num',
#  'init_encumbrance_date',
#  'can_task',
#  'special_topic_code',
#  'agency_code',
#  'covid_response',
#  'arra_funded',
#  'budget_start',
#  'budget_end',
#  'cfda_code',
#  'funding_mechanism',
#  'direct_cost_amt',
#  'indirect_cost_amt',
#  'project_detail_url',
#  'date_added',
#  'api_source_search']

# %%
# Define columns to keep. Select those that  match info in the current INS projects.tsv.
# project_type, lead_doc, and award_amount_category will be derived later

select_cols = [
    'project_num',
    'core_project_num',
    'appl_id',
    'fiscal_year',
    'project_title',
    'abstract_text',
    'pref_terms',
    'org_name',
    'org_city',
    'org_state',
    'org_country',
    'principal_investigators',
    'program_officers',
    'award_amount',
    'agency_ic_fundings',
    'award_notice_date',
    'project_start_date',
    'project_end_date',
    'full_foa',
]

# %%
# Select only the columns of interest defined above in a new dataframe
df_grants_select = df_grants[select_cols]

# %%
# In the grants JSON above, the PI column was nested. Check how the column 
# appears within the dataframe. 
df_grants_select['principal_investigators']
# Out:
# 0       [{'profile_id': 1873123, 'first_name': 'COLLEE...
# 1       [{'profile_id': 1873123, 'first_name': 'COLLEE...
# 2       [{'profile_id': 11856998, 'first_name': 'Jada'...
# 3       [{'profile_id': 11856998, 'first_name': 'Jada'...
# 4       [{'profile_id': 8950071, 'first_name': 'Rebecc...
#                               ...
# 3181    [{'profile_id': 12302905, 'first_name': 'Benja...
# 3182    [{'profile_id': 10131112, 'first_name': 'Joe',...
# 3183    [{'profile_id': 15167932, 'first_name': 'Gavin...
# 3184    [{'profile_id': 15056131, 'first_name': 'Luisa...
# 3185    [{'profile_id': 12628430, 'first_name': 'Cheng...
# Name: principal_investigators, Length: 3186, dtype: object

# %% [markdown]
# ### Explore how to flatten and clean up the grants data for downstream use

# %% [markdown]
# The following columns are multi-level json and need to be handled:
# * `principal_investigators`
# * `program_officers`
# * `agency_ic_fundings`
#
# Example Structures:
# 'principal_investigators': [{'profile_id': 1873123,
#     'first_name': 'COLLEEN',
#     'middle_name': 'M',
#     'last_name': 'MC BRIDE',
#     'is_contact_pi': True,
#     'full_name': 'COLLEEN M MC BRIDE',
#     'title': 'GRACE CRUM ROLLINS PROFESSOR AND CHAIR',
#     'email': None}],
# ...
#   'program_officers': [{'first_name': 'VERONICA',
#     'middle_name': '',
#     'last_name': 'CHOLLETTE',
#     'full_name': 'VERONICA  CHOLLETTE',
#     'email': None}],
# ...
#   'agency_ic_fundings': [{'fy': 2020,
#     'code': 'CA',
#     'name': 'National Cancer Institute',
#     'abbreviation': 'NCI',
#     'total_cost': 185323.0}],
#
#
# We need to extract values of interest, combine them, and then clean them as necessary.

# %%
def concatenate_full_names(row):
    """Replace json row values with full names list from within json"""

    # Check for blank row, then get each full name
    if row:
        full_names = [item['full_name'] for item in row]

        # Concatenate with a comma space between
        return ', '.join(full_names)
    else:
        # Return blank output for blank input
        return ''

# %%
# Test function aboe. Get the full name of investigators from the nested values
df_grants_select['principal_investigators'].apply(concatenate_full_names)
# Out:
# 0                                      COLLEEN M MC BRIDE
# 1                                      COLLEEN M MC BRIDE
# 2                                 Jada Gabrielle Hamilton
# 3                                 Jada Gabrielle Hamilton
# 4       Rebecca  Ashare, Salimah H. Meghani, Brooke  W...
#                               ...
# 3181                           Benjamin Peter Kleinstiver
# 3182                                        Joe R Delaney
# 3183                                            Gavin  Ha
# 3184                                 Luisa  Escobar Hoyos
# 3185                                      Chengcheng  Jin
# Name: principal_investigators, Length: 3186, dtype: object

# %%
# Get the full name of POs from the nested values
df_grants_select['program_officers'].apply(concatenate_full_names)
# Out:
# 0       VERONICA  CHOLLETTE
# 1       VERONICA  CHOLLETTE
# 2             Wendy  Nelson
# 3             Wendy  Nelson
# 4            SHARON A. ROSS
#                ...
# 3181              Jerry  Li
# 3182           Stefan  Maas
# 3183       Miguel  Ossandon
# 3184               Yin  Liu
# 3185    Phillip J. Daschner
# Name: program_officers, Length: 3186, dtype: object

# %% [markdown]
# The name columns (PI and PO) have inconsistent capitalization and spacing. Fix that for better presentation.
# Standardize names by capitalizing the first letter of each word and keeping all others lower-case.
#
# This method will lose some nuance in name capitalization, e.g.:
# * "da Vinci" will become "Da Vinci"
# * "McKinley" will become "Mckinley"
# * "Mc Kinley" will stay "Mc Kinley"

# %%
def format_name_column(name_str):
    # Capitalize the first letter of each name
    formatted_name = name_str.title()
    
    # Remove double whitespaces between names
    formatted_name = formatted_name.replace('  ',' ')
    
    return formatted_name

# %%
# Check name concatenation and standardization (applied together) for investigators.
df_grants_select['principal_investigators'].apply(concatenate_full_names).apply(format_name_column)
# Out:
# 0                                      Colleen M Mc Bride
# 1                                      Colleen M Mc Bride
# 2                                 Jada Gabrielle Hamilton
# 3                                 Jada Gabrielle Hamilton
# 4       Rebecca Ashare, Salimah H. Meghani, Brooke Wor...
#                               ...
# 3181                           Benjamin Peter Kleinstiver
# 3182                                        Joe R Delaney
# 3183                                             Gavin Ha
# 3184                                  Luisa Escobar Hoyos
# 3185                                       Chengcheng Jin
# Name: principal_investigators, Length: 3186, dtype: object

# %%
# Check name concatenation and standardization (applied together) for POs
df_grants_select['program_officers'].apply(concatenate_full_names).apply(format_name_column)
# Out:
# 0        Veronica Chollette
# 1        Veronica Chollette
# 2              Wendy Nelson
# 3              Wendy Nelson
# 4            Sharon A. Ross
#                ...
# 3181               Jerry Li
# 3182            Stefan Maas
# 3183        Miguel Ossandon
# 3184                Yin Liu
# 3185    Phillip J. Daschner
# Name: program_officers, Length: 3186, dtype: object

# %%
# Define columns with nested name values
name_cols = ['principal_investigators', 'program_officers']

# Copy dataframe to avoid SettingWithCopyWarning error
df_formatted = df_grants_select.copy()

# Apply name corrections to all rows
df_formatted[name_cols] = (df_formatted[name_cols]
                               .apply(lambda col: col
                                      .apply(concatenate_full_names)
                                      .apply(format_name_column)))

# %%
# Check formatting of name columns within first ten rows of dataframe
df_formatted[['project_num', 'principal_investigators','program_officers']].head(10)
# Out:
#          project_num                            principal_investigators  \
# 0    5R21CA238356-02                                 Colleen M Mc Bride
# 1  1R21CA238356-01A1                                 Colleen M Mc Bride
# 2    5R21CA230879-02                            Jada Gabrielle Hamilton
# 3    1R21CA230879-01                            Jada Gabrielle Hamilton
# 4    5R01CA270483-02  Rebecca Ashare, Salimah H. Meghani, Brooke Wor...
# 5    1R01CA270483-01  Rebecca Ashare, Salimah H. Meghani, Brooke Wor...
# 6    5R01CA264984-03                                  Mikhail Nikiforov
# 7    5R01CA268597-02                Colin Goding, Constantinos Koumenis
# 8    5R01CA259469-02   Nitin S Baliga, Charles S Cobbs, Parvinder Hothi
# 9    5R01CA251545-03                                       Gokul M. Das
#
#       program_officers
# 0   Veronica Chollette
# 1   Veronica Chollette
# 2         Wendy Nelson
# 3         Wendy Nelson
# 4       Sharon A. Ross
# 5   Alexis Diane Bakos
# 6   Thomas K. Howcroft
# 7  Elizabeth Woodhouse
# 8    Joseph Kofi Agyin
# 9     Joanna M. Watson

# %% [markdown]
# Names are handled. Now to extract the NCI funding from the nested agency funding column.
# The API query above selects only grants where NCI is providing administrative support. This step will extract the actual funding NCI is providing, which in some cases may be zero.
#
# This means that the current approach is gathering NCI-supported grants, but not necessarily NCI-funded grants.
# We are not gathering the converse of this, where NCI is not the admin but is providing funding.

# %%
# Check format of first value in nested funding column
df_formatted['agency_ic_fundings'][0]
# Out:
# [{'fy': 2021,
#   'code': 'CA',
#   'name': 'National Cancer Institute',
#   'abbreviation': 'NCI',
#   'total_cost': 216667.0}]

# %%
# Check for rows with more than one set of nested funding values
nested_values = df_formatted['agency_ic_fundings'].apply(len)
df_formatted[nested_values > 1]['agency_ic_fundings']
# Out:
# 176     [{'fy': 2023, 'code': 'CA', 'name': 'National ...
# 444     [{'fy': 2023, 'code': 'CA', 'name': 'National ...
# 728     [{'fy': 2023, 'code': 'CA', 'name': 'National ...
# 1210    [{'fy': 2023, 'code': 'CA', 'name': 'National ...
# 1421    [{'fy': 2022, 'code': 'CA', 'name': 'National ...
# 1564    [{'fy': 2022, 'code': 'CA', 'name': 'National ...
# 1664    [{'fy': 2022, 'code': 'CA', 'name': 'National ...
# 1865    [{'fy': 2022, 'code': 'CA', 'name': 'National ...
# 2788    [{'fy': 2022, 'code': 'CA', 'name': 'National ...
# 2864    [{'fy': 2022, 'code': 'CA', 'name': 'National ...
# 2880    [{'fy': 2022, 'code': 'CA', 'name': 'National ...
# 2921    [{'fy': 2022, 'code': 'CA', 'name': 'National ...
# 2923    [{'fy': 2022, 'code': 'CA', 'name': 'National ...
# 2925    [{'fy': 2022, 'code': 'CA', 'name': 'National ...
# 2977    [{'fy': 2021, 'code': 'CA', 'name': 'National ...
# 3180    [{'fy': 2022, 'code': 'CA', 'name': 'National ...
# Name: agency_ic_fundings, dtype: object

# %% [markdown]
# Some `agency_ic_fundings` values list multiple agencies with details for each.
# This is worth keeping for reference, but relies on API data that will be removed before exporting to project TSVs. (We only keep the NCI and total fundings)

# %%
def find_projects_with_multiple_agencies(df):
    """Find rows in grants dataframe that have multiple funding agencies"""
    
    selected_rows = []

    # Iterate through each row in the dataframe
    for index, row in df.iterrows():
        agency_fundings = row['agency_ic_fundings']

        # Check if there are multiple agency fundings for the project
        if len(agency_fundings) > 1:
            nci_funding = None
            other_funding = []

            # Separate NCI and other fundings
            for entry in agency_fundings:
                if entry['abbreviation'] == 'NCI':
                    nci_funding = entry['total_cost']
                else:
                    other_funding.append(entry)

            # Create a new row in selected_rows for each other agency funding
            for other_entry in other_funding:
                row_data = {
                    'project_num': row['project_num'],
                    'code': other_entry['code'],
                    'name': other_entry['name'],
                    'abbreviation': other_entry['abbreviation'],
                    'other_cost': other_entry['total_cost'],
                    'nci_cost': nci_funding
                }
                selected_rows.append(row_data)

    # Create a new dataframe from the selected rows
    selected_df = pd.DataFrame(selected_rows)

    return selected_df

# %%
# Run function to get df of funding from other agencies for each project
df_other_funding = find_projects_with_multiple_agencies(df_formatted)

df_other_funding.head(20)
# Out:
#           project_num code                                            name  \
# 0     5R01CA267554-02   GM  National Institute of General Medical Sciences
# 1     5R01CA263504-02   GM  National Institute of General Medical Sciences
# 2     5R01CA266415-02   GM  National Institute of General Medical Sciences
# 3     5R01CA263747-02   GM  National Institute of General Medical Sciences
# 4   1R01CA267554-01A1   GM  National Institute of General Medical Sciences
# 5   1R01CA263504-01A1   GM  National Institute of General Medical Sciences
# 6   1R01CA263747-01A1   GM  National Institute of General Medical Sciences
# 7   1R01CA266415-01A1   GM  National Institute of General Medical Sciences
# 8   3P30CA076292-24S7   OD                      NIH Office of the Director
# 9   3P30CA016058-46S3   OD                      NIH Office of the Director
# 10  3P30CA014089-46S2   OD                      NIH Office of the Director
# 11  3P30CA016087-41S3   OD                      NIH Office of the Director
# 12  3P30CA016359-43S4   OD                      NIH Office of the Director
# 13  3P30CA082103-23S4   OD                      NIH Office of the Director
# 14  3U54CA225088-04S1   OD                      NIH Office of the Director
# 15    1DP2CA281605-01   OD                      NIH Office of the Director
#
#    abbreviation  other_cost  nci_cost
# 0         NIGMS    320000.0   21745.0
# 1         NIGMS    320000.0   24109.0
# 2         NIGMS    313600.0   32047.0
# 3         NIGMS    320000.0   11736.0
# 4         NIGMS    320000.0   22189.0
# 5         NIGMS    320000.0   31131.0
# 6         NIGMS    320000.0   18506.0
# 7         NIGMS    320000.0   33224.0
# 8            OD     96290.0   53709.0
# 9            OD     50000.0   50000.0
# 10           OD     50000.0  100000.0
# 11           OD     50000.0  100000.0
# 12           OD     50000.0   99998.0
# 13           OD     50000.0  100000.0
# 14           OD    126750.0  126750.0
# 15           OD   1291731.0  188769.0

# %%
def extract_total_cost(fundings):
    """Extract the total NCI funding from IC award totals"""

    for funding in fundings:
        # CA is the NCI code
        if funding['code'] == 'CA':
            return int(funding['total_cost'])
    # Return 0 if no NCI funding found
    return int(0)

# %%
# Replace the nested column with one just for NCI funding amount
df_formatted['agency_ic_fundings'] = (df_formatted['agency_ic_fundings']
                                        .apply(extract_total_cost))

# %%
# Check first 10 rows of new funding column
df_formatted[['project_num','agency_ic_fundings']].head(10)
# Out:
#          project_num  agency_ic_fundings
# 0    5R21CA238356-02              216667
# 1  1R21CA238356-01A1              185323
# 2    5R21CA230879-02              227347
# 3    1R21CA230879-01              186724
# 4    5R01CA270483-02              642629
# 5    1R01CA270483-01              699429
# 6    5R01CA261691-03              556856
# 7  1R01CA272991-01A1              526386
# 8  1R01CA273716-01A1              655228
# 9  1R01CA273357-01A1              634435

# %% [markdown]
# ### Rename columns to match expected values within INS-ETL

# %%
# Create a dict with old:expected col names
expected_col_rename_dict = {
    "project_num": "project_id",
    "core_project_num": "queried_project_id",
    "appl_id": "application_id",
    "pref_terms": "keywords",
    "agency_ic_fundings": "nci_funded_amount"
}

# %%
# Check new INS names
df_formatted.rename(columns=expected_col_rename_dict).head()
# Out:
#           project_id queried_project_id  application_id  fiscal_year  \
# 0    5R21CA238356-02        R21CA238356        10064138         2021
# 1  1R21CA238356-01A1        R21CA238356         9893342         2020
# 2    5R21CA230879-02        R21CA230879         9728901         2019
# 3    1R21CA230879-01        R21CA230879         9582452         2018
# 4    5R01CA270483-02        R01CA270483        10610465         2023
#
#                                        project_title  \
# 0  Evaluating Deliberative Democracy Approaches w...
# 1  Evaluating Deliberative Democracy Approaches w...
# 2  Responses to Genetic Risk Modifier Testing Amo...
# 3  Responses to Genetic Risk Modifier Testing Amo...
# 4  Cannabis use and outcomes in ambulatory patien...
#
#                                        abstract_text  \
# 0  PROJECT SUMMARY\nSeveral national organization...
# 1  PROJECT SUMMARY\nSeveral national organization...
# 2  PROJECT SUMMARY\nWomen with a BRCA1/2 gene mut...
# 3  PROJECT SUMMARY\nWomen with a BRCA1/2 gene mut...
# 4  PROJECT ABSTRACT\nBetween 24-40% of cancer pat...
#
#                                             keywords  \
# 0  Address;Adoption;African;Agreement;Area;Awaren...
# 1  Address;Adoption;African;Agreement;Area;Awaren...
# 2  Address;Adverse effects;Affect;Age;BRCA1 gene;...
# 3  Address;Adverse effects;Affect;Age;BRCA1 gene;...
# 4  Adjuvant Analgesic;Adult;African American;Amer...
#
#                             org_name      org_city org_state    org_country  \
# 0                   EMORY UNIVERSITY       ATLANTA        GA  UNITED STATES
# 1                   EMORY UNIVERSITY       ATLANTA        GA  UNITED STATES
# 2  SLOAN-KETTERING INST CAN RESEARCH      NEW YORK        NY  UNITED STATES
# 3  SLOAN-KETTERING INST CAN RESEARCH      NEW YORK        NY  UNITED STATES
# 4         UNIVERSITY OF PENNSYLVANIA  PHILADELPHIA        PA  UNITED STATES
#
#                              principal_investigators    program_officers  \
# 0                                 Colleen M Mc Bride  Veronica Chollette
# 1                                 Colleen M Mc Bride  Veronica Chollette
# 2                            Jada Gabrielle Hamilton        Wendy Nelson
# 3                            Jada Gabrielle Hamilton        Wendy Nelson
# 4  Rebecca Ashare, Salimah H. Meghani, Brooke Wor...      Sharon A. Ross
#
#    award_amount  nci_funded_amount     award_notice_date  \
# 0        216667             216667  2020-11-24T12:11:00Z
# 1        185323             185323  2019-12-02T12:12:00Z
# 2        227347             227347  2019-05-17T12:05:00Z
# 3        186724             186724  2018-06-20T12:06:00Z
# 4        642629             642629  2023-05-02T12:05:00Z
#
#      project_start_date      project_end_date   full_foa
# 0  2019-12-03T12:12:00Z  2022-11-30T12:11:00Z  PA-17-446
# 1  2019-12-03T12:12:00Z  2021-11-30T12:11:00Z  PA-17-446
# 2  2018-06-20T12:06:00Z  2022-05-31T12:05:00Z  PA-17-446
# 3  2018-06-20T12:06:00Z  2020-05-31T12:05:00Z  PA-17-446
# 4  2022-04-15T12:04:00Z  2027-03-31T12:03:00Z  PA-18-917

# %% [markdown]
# This looks good, though I still need to add in some INS idiosyncrasies later:
# * `project_type`=`Grant` (hardcoded for now)
# * assign `lead_doc` using Key Player. Will get tricky for shared grants/NOFOs
# * `award_amount_category` (e.g. $4M to $10M)

# %% [markdown]
# ### Gathering and cleaning so far have used a single input
# Try using the cleaned key programs file as input and gathering/cleaning all provided NOFO/Award values

# %%
# Set filepath using config
key_programs_path = f"../{config.CLEANED_KEY_PROGRAMS_CSV}"

# Load cleaned Key Programs CSV as a dataframe
df_key_programs = pd.read_csv(key_programs_path)

# %%
# Check loaded dataframe
df_key_programs.head()
# Out:
#                                         program_name program_acronym  \
# 0  Pancreatic Adenocarcinoma Stromal Reprograming...   PSRC/PASSCODE
# 1                        Oncology Models Forum (U24)             OMF
# 2     Pediatric Preclinical in Vivo Testing (PIVOT)            PIVOT
# 3                    Cancer Immunologic Data Commons            CIDC
# 4      CANCER IMMUNE MONITORING AND ANALYSIS CENTERS           CIMAC
#
#                           focus_area            doc       contact_pi  \
# 0                                DCC       DCB,DCTD  MAITRA, ANIRBAN
# 1                DCC,Cancer Moonshot            DCB    BUTTE, ATUL J
# 2  Pediatric/AYA,DCC,Cancer Moonshot  CIB,CTEP,DCTD    BULT, CAROL J
# 3                    Cancer Moonshot           DCTD    CERAMI, ETHAN
# 4                    Cancer Moonshot      CTEP,DCTD              NaN
#
#            contact_pi_email                      contact_nih  \
# 0    amaitra@mdanderson.org  Hildesheim, Jeff; UJHAZY, PETER
# 1       atul.butte@ucsf.edu   Christine Nadeau;Joanna Watson
# 2        carol.bult@jax.org                  Smith, Malcolm
# 3  cerami@jimmy.harvard.edu                THURIN, MAGDALENA
# 4                       NaN                Thurin, Magdalena
#
#                                 contact_nih_email  \
# 0  hildesheimj@mail.nih.gov; ujhazyp@mail.nih.gov
# 1  christine.nadeau@nih.gov;watsonjo@mail.nih.gov
# 2                           Malcolm.Smith@nih.gov
# 3                            thurinm@mail.nih.gov
# 4                            thurinm@mail.nih.gov
#
#                                             nofo              award  \
# 0                   RFA-CA-21-041; RFA-CA-21-042  1 U24 CA274274-01
# 1  PAR14-239; PAR-16-059; PAR-17-245; PAR-20-131       5U24CA195858
# 2    RFA-CA-20-034; RFA-CA-14-018; RFA-CA-20-041        U24CA263963
# 3                   RFA-CA-17-006; RFA-CA-22-038       1U24CA224316
# 4                    RFA-CA-17-005;RFA-CA-22-038                NaN
#
#                                         program_link data_link  \
# 0  https://www.cancer.gov/about-nci/organization/...       NaN
# 1  https://www.cancer.gov/about-nci/organization/...       NaN
# 2  https://ctep.cancer.gov/MajorInitiatives/Pedia...       NaN
# 3  https://dctd.cancer.gov/ResearchNetworks/cimac...       NaN
# 4  https://dctd.cancer.gov/ResearchNetworks/cimac...       NaN
#
#                                          cancer_type
# 0                                    Pancreas Cancer
# 1  This program focuses on cancer broadly - not l...
# 2  This program focuses on cancer broadly - not l...
# 3  This program focuses on cancer broadly - not l...
# 4  This program focuses on cancer broadly - not l...

# %%
# Try pulling and formatting NOFO list from each program into useable format
for index, row in df_key_programs.iterrows():
    program_name = row['program_name']
    nofo_str = row['nofo']

    # Check for NaN value to avoid error on split()    
    if pd.isna(nofo_str):
        print(f"{program_name}: No NOFOs defined.")
        
    # Separate NOFOs by semicolon, remove spaces, and then add to list
    else:
        nofo_list = [x.strip() for x in nofo_str.split(';')]
        print(f"{program_name}: {nofo_list}")
# Out:
# Pancreatic Adenocarcinoma Stromal Reprograming ConSortium (PSRC/PASSCODE): ['RFA-CA-21-041', 'RFA-CA-21-042']
# Oncology Models Forum (U24): ['PAR14-239', 'PAR-16-059', 'PAR-17-245', 'PAR-20-131']
# Pediatric Preclinical in Vivo Testing (PIVOT) : ['RFA-CA-20-034', 'RFA-CA-14-018', 'RFA-CA-20-041']
# Cancer Immunologic Data Commons: ['RFA-CA-17-006', 'RFA-CA-22-038']
# CANCER IMMUNE MONITORING AND ANALYSIS CENTERS: ['RFA-CA-17-005', 'RFA-CA-22-038']
# Cellular Cancer Biology Imaging Research: ['RFA-CA-21-002']
# Barrett’s Esophagus Translational Research Network (BETRNet): ['RFA-CA-16-007', 'RFA-CA-16-006', 'RFA-CA-10-014']
# Fusion Oncoproteins in Childhood Cancers (FusOnc2): ['RFA-CA-17-049', 'RFA-CA-19-016']
# The Early Detection Research Network (EDRN): ['CA-14-017', 'CA-21-034', 'CA-21-033', 'CA-21-035', 'CA-14-015', 'CA-14-016', 'CA-16-009']
# Cancer Prevention-Interception Targeted Agent Discovery Program: ['RFA-CA-21-038', 'RFA-CA-22-055', 'RFA-CA-21-039']
#  Small Cell Lung Cancer (SCLC) Consortium : ['PAR21-346', 'PAR-16-049', 'PAR-16-050', 'PAR-16-051', 'PAR-19-361']
# Acquired Resistance to Therapy Network (ARTNet): ['RFA-CA-21-052', 'RFA-CA-21-053']
# All of Us: ['HG21-041', 'LM21-002', 'MH22-200', 'OD21-144', 'OD22-150', 'OD22-153', 'OTA17-002', 'OTA18-001', 'OTA19-002', 'OTA19-003', 'OTA19-004', 'OTA20-001', 'OTA20-009', 'OTA22-006', 'OTA23-001', 'OTA23-003', 'A17-446', 'PA18-91', 'PA20-145', 'PA20-185', 'PA20-272', 'PAR20-150', 'PM23-001', 'PM23-002', 'RM21-002', 'RM21-003', 'RM21-005', 'RM21-006', 'RM21-016', 'SM18-009', 'SM21-007', 'SP20-002']
# Childhood Cancer Survivor Study: ['RFA-CA-20-052', 'RFA-CA15-502']
# The Adjuvant Lung Cancer Enrichment Marker Identification and Sequencing Trials (ALCHEMIST): No NOFOs defined.
# PaCMEN: ['RFA-CA-17-015', 'RFA-CA-17-016']
# AIDS and Cancer Specimen Resource (ACSR): ['RFA-CA-18-012']
# SPORE in Bladder Cancer: No NOFOs defined.
# SPORE: Targeted Therapies for Glioma: No NOFOs defined.
# The Memorial Sloan Kettering Cancer Center SPORE in Leukemia: No NOFOs defined.
# The University of Texas MD Anderson Cancer Center SPORE in Hepatocellular Carcinoma: No NOFOs defined.
# Brain Tumor SPORE Grant: No NOFOs defined.
# Vanderbilt-Ingram Cancer Center SPORE in Gastrointestinal Cancer: No NOFOs defined.
# ADMIRAL Study: Admixture analysis of acute lymphoblastic leukemia in African American children: No NOFOs defined.
# SPORE in Myeloid Malignancies: No NOFOs defined.
# Yale SPORE in Lung Cancer (YSILC): The Biology and Personalized Treatment of Lung Cancer: No NOFOs defined.
# Fred Hutchinson Cancer Research Center Lung SPORE: No NOFOs defined.

# %%
# Pull API fields to keep from config
select_cols = config.API_FIELDS
select_cols
# Out:
# ['project_num',
#  'core_project_num',
#  'appl_id',
#  'fiscal_year',
#  'project_title',
#  'abstract_text',
#  'pref_terms',
#  'org_name',
#  'org_city',
#  'org_state',
#  'org_country',
#  'principal_investigators',
#  'program_officers',
#  'award_amount',
#  'agency_ic_fundings',
#  'award_notice_date',
#  'project_start_date',
#  'project_end_date',
#  'full_foa',
#  'api_source_search']

# %%
# Remove spaces and non-alphanumeric characters from program name for filename
for program_name in df_key_programs['program_name']:
    newName = ''.join(filter(str.isalnum, program_name))
    print(newName)
# Out:
# PancreaticAdenocarcinomaStromalReprogramingConSortiumPSRCPASSCODE
# OncologyModelsForumU24
# PediatricPreclinicalinVivoTestingPIVOT
# CancerImmunologicDataCommons
# CANCERIMMUNEMONITORINGANDANALYSISCENTERS
# CellularCancerBiologyImagingResearch
# BarrettsEsophagusTranslationalResearchNetworkBETRNet
# FusionOncoproteinsinChildhoodCancersFusOnc2
# TheEarlyDetectionResearchNetworkEDRN
# CancerPreventionInterceptionTargetedAgentDiscoveryProgram
# SmallCellLungCancerSCLCConsortium
# AcquiredResistancetoTherapyNetworkARTNet
# AllofUs
# ChildhoodCancerSurvivorStudy
# TheAdjuvantLungCancerEnrichmentMarkerIdentificationandSequencingTrialsALCHEMIST
# PaCMEN
# AIDSandCancerSpecimenResourceACSR
# SPOREinBladderCancer
# SPORETargetedTherapiesforGlioma
# TheMemorialSloanKetteringCancerCenterSPOREinLeukemia
# TheUniversityofTexasMDAndersonCancerCenterSPOREinHepatocellularCarcinoma
# BrainTumorSPOREGrant
# VanderbiltIngramCancerCenterSPOREinGastrointestinalCancer
# ADMIRALStudyAdmixtureanalysisofacutelymphoblasticleukemiainAfricanAmericanchildren
# SPOREinMyeloidMalignancies
# YaleSPOREinLungCancerYSILCTheBiologyandPersonalizedTreatmentofLungCancer
# FredHutchinsonCancerResearchCenterLungSPORE

# %% [markdown]
# Not shown here: some ad-hoc analyses investigating odd gathering results for the ALCHEMIST Program.

# %% [markdown]
# The NOFOs for ALCHEMIST are actually Award numbers. Looking back at the key_programs.tsv, there was a shift in columns on that row.
# Maybe a csv -> df -> tsv issue. Switched all formats to csv. (Update: Frame-shift issue was present in the raw data, so not a filetype conversion issue)
# Added a `qualtrics_output_2023-07-19_manual_fix.csv` in which the following are corrected:
# * Column shift starting with NOFOs in ALCHEMIST
# * Removed extra semicolon in All of Us NOFOs that split PA18-91 into PA18- and 91
#
#
# Updated config to point to this manually fixed csv instead of the original. Eventually need code to detect and/or fix these automatically.
# Also getting some odd encoding behavior whenever the raw qualtrics csv is manually edited. Especially the last column name newline in "check all that \n apply"

# %% [markdown]
# ## Add in Grants data when specified in qualtrics csv

# %% [markdown]
# Reuse and tweak the function used to call the API for NOFOs. There's probably a more clever way to do this.

# %%
# OBSOLETE, replaced later by get_nih_repoter_grants
def get_nih_reporter_grants_from_award(award_values:str, print_meta=False):
    """Get grants info for provided Award Numbers.
    
    :param award_values: string of core projects and/or awards separated 
        separated by semicolons. 

    :param print_meta: boolean indicator. If True, print API gathering process
        results to console"""

    base_url = "https://api.reporter.nih.gov/v2/projects/search"
    grants_data = []

    for award in award_values:
        # Check for blank Award values
        if not award:
            print(f"Blank award value encountered. Skipping.")
            continue

        # Set default values for params not likley to change
        LIMIT = 500
        MAX_ATTEMPTS = 5
        RETRY_TIME = 2

        # Set starting value for counters
        offset = 0
        page = 0
        attempts = 0

        # RePORTER API sets a max limit of 500 records per call.
        # Keep looping each call in "pages" until the number of records 
        # gathered reaches the total number of records available. 
        
        # Set a cap on the number of attempts at a failed call before 
        # moving on to the next award.
        while attempts < MAX_ATTEMPTS:
            # Set parameters for API call
            params = {
                "criteria": {
                    "project_nums": [award],
                    "exclude_subprojects": True,
                    "agencies": ["NCI"]
                },
                "limit": LIMIT,
                "offset": offset,
                "sort_field": "FiscalYear",
                "sort_order": "desc",
            }

            try: 
                # Define response details
                response = requests.post(base_url, 
                                        json=params, 
                                        headers={
                                            "accept": "application/json", 
                                            "Content-Type": "application/json"})

                # If response is good, get results
                if response.status_code == 200:
                    grants = response.json()
                    # Add API source indicator
                    for grant in grants['results']:
                        grant['api_source_search'] = f"Award_search: {award}"
                    # Add grants to running list
                    grants_data.extend(grants['results'])

                    # Increase offset by limit to get next "page"
                    total_records = grants['meta']['total']
                    offset = offset + LIMIT
                    page = page + 1

                    # Print paginated partial optional metadata
                    # Consider replacing this with proper logging
                    if print_meta == True:
                        total_pages = max(ceil(total_records/LIMIT),1)
                        print(f"Award Results: {award} ({page}/{total_pages}):"
                              f" {grants['meta']}")

                    # Stop looping if offset has reached total record count
                    if offset >= total_records:
                        break

                # Handle 500 errors by retrying after 2 second delay
                elif response.status_code == 500:
                    attempts = attempts + 1
                    print(f"Received a 500 error for Aroject '{award}'. "
                          f"Retrying after {RETRY_TIME} seconds. "
                          f"Attempt {attempts}/{MAX_ATTEMPTS}")
                    sleep(RETRY_TIME)
                else:
                    print(f"Error occurred while fetching grants for Award "
                          f"'{award}': {response.status_code}")
                    break

            except requests.exceptions.RequestException as e:
                print(f"An error occurred while making the API call for "
                      f"Award'{award}': {e}")
                break

    return grants_data

# %% [markdown]
# Test the award-based gathering on a single Program with Awards listed

# %%
# Copy/Pase the PaCMEN Qualtrics Award cell, and convert string to list
PaCMEN_string = "U01CA224146; U01CA224193-01; 4U01CA224348-02"
PaCMEN_listed = PaCMEN_string.split(';')

# Use list of PaCMEN awards as award_values
award_values = PaCMEN_listed

# Run grants_data
pacmen_grants_data = get_nih_reporter_grants_from_award(award_values, print_meta=True)

print(f"Total records gathered: {len(pacmen_grants_data)}")
# Out:
# Award Results: U01CA224146 (1/1): {'search_id': 'nyqgRG1wA0G3yTdXozjvdw', 'total': 3, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/nyqgRG1wA0G3yTdXozjvdw/projects'}}
# Award Results:  U01CA224193-01 (1/1): {'search_id': 'AoBk7GHFFUGb5XfJSya4Eg', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/AoBk7GHFFUGb5XfJSya4Eg/projects'}}
# Award Results:  4U01CA224348-02 (1/1): {'search_id': 'UoEURctrv0qBX83NonhcqQ', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/UoEURctrv0qBX83NonhcqQ/projects'}}
# Total records gathered: 5

# %%
# Quick test of converting award-gathered grants to dataframe
df_pacmen = pd.DataFrame(pacmen_grants_data)
df_pacmen.head()
# Out:
#     appl_id subproject_id  fiscal_year  \
# 0  10250566          None         2021
# 1  10242454          None         2020
# 2   9449587          None         2017
# 3   9450411          None         2017
# 4  10242459          None         2020
#
#                                  org_name org_city org_state org_state_name  \
# 0                 DANA-FARBER CANCER INST   BOSTON        MA           None
# 1                 DANA-FARBER CANCER INST   BOSTON        MA           None
# 2                 DANA-FARBER CANCER INST   BOSTON        MA           None
# 3  FRED HUTCHINSON CANCER RESEARCH CENTER  SEATTLE        WA           None
# 4          MASSACHUSETTS GENERAL HOSPITAL   BOSTON        MA           None
#
#   dept_type      project_num project_serial_num  ... arra_funded  \
# 0      None  5U01CA224146-03           CA224146  ...           N
# 1      None  4U01CA224146-02           CA224146  ...           N
# 2      None  1U01CA224146-01           CA224146  ...           N
# 3      None  1U01CA224193-01           CA224193  ...           N
# 4      None  4U01CA224348-02           CA224348  ...           N
#
#            budget_start            budget_end cfda_code  funding_mechanism  \
# 0  2021-09-01T12:09:00Z  2022-08-31T12:08:00Z       353      Non-SBIR/STTR
# 1  2020-09-01T12:09:00Z  2021-08-31T12:08:00Z       353      Non-SBIR/STTR
# 2  2017-09-30T12:09:00Z  2020-08-31T12:08:00Z       353      Non-SBIR/STTR
# 3  2017-09-30T12:09:00Z  2020-08-31T12:08:00Z       353      Non-SBIR/STTR
# 4  2020-09-01T12:09:00Z  2021-08-31T12:08:00Z       353      Non-SBIR/STTR
#
#    direct_cost_amt  indirect_cost_amt  \
# 0           350000             261615
# 1           350000             261615
# 2          1050000             795039
# 3          1389466             457363
# 4           350000             227095
#
#                                   project_detail_url            date_added  \
# 0  https://reporter.nih.gov/project-details/10250566  2021-09-04T04:09:59Z
# 1  https://reporter.nih.gov/project-details/10242454  2020-09-05T07:09:23Z
# 2   https://reporter.nih.gov/project-details/9449587  2017-10-01T02:10:16Z
# 3   https://reporter.nih.gov/project-details/9450411  2017-10-01T02:10:16Z
# 4  https://reporter.nih.gov/project-details/10242459  2020-09-05T07:09:23Z
#
#                 api_source_search
# 0       Award_search: U01CA224146
# 1       Award_search: U01CA224146
# 2       Award_search: U01CA224146
# 3   Award_search:  U01CA224193-01
# 4  Award_search:  4U01CA224348-02
#
# [5 rows x 58 columns]

# %% [markdown]
# Looks promising. Use the stand-in `process_program` function to add award-gathered grants data to nofo-gathered grants data and clean all in a loop.

# %% [markdown]
# To iterate through each program, we need to gather and clean during the loop. Make a placeholder cleaning function.

# %%
def clean_grants_data(grants_data, select_cols):
    """Create clean dataframes from JSON API responses."""
    
    # Load JSON as dataframe
    df_grants = pd.DataFrame(grants_data)

    df_grants_selected = df_grants[select_cols]

    # Other cleaning steps 
    # ... 
    clean_grants = df_grants_selected.copy()
    #...

    return clean_grants

# %%
# THIS FUNCTION IS OVERWRITTEN LATER IN THE NOTEBOOK
def process_program(program_name, nofo_list, award_list, select_cols):
    """Create grants TSVs for each key program."""

    # Get grants data using NIH RePORTEr API
    nofo_grants_data = get_nih_reporter_grants_from_nofo(nofo_list, print_meta=True)
    award_grants_data = get_nih_reporter_grants_from_award(award_list, print_meta=True)

    # Combine data
    grants_data = nofo_grants_data + award_grants_data

    # Create dataframe and clean grants data
    clean_grants = clean_grants_data(grants_data, select_cols)

    # Export grants data as tsv for each program
    # TEST EXPORT DISABLED TO AVOID FUTURE CONFUSION
    # Use program names with only alphanumeric characters for filename
    # file_name = f"{''.join(filter(str.isalnum, program_name))}.csv" # Changed to csv
    # clean_grants.to_csv(file_name, index=False)

# %%
# Iterate through nofos and awards for each program
for index, row in df_key_programs.iterrows():
    program_name = row['program_name']
    nofo_str = row['nofo']
    award_str = row['award']

    print(f"---\n{program_name}")

    # Skip any programs where no funding is provided
    if pd.isna(nofo_str) and pd.isna(award_str):
        print(f"No NOFOs or Awards defined. Skipping.")
    else:
        nofo_list = [] if pd.isna(nofo_str) else [x.strip() for x in nofo_str.split(';')]
        award_list = [] if pd.isna(award_str) else [x.strip() for x in award_str.split(';')]

        if not nofo_list:
            process_program(program_name, nofo_list, award_list, select_cols)
        elif not award_list:
            process_program(program_name, nofo_list, award_list, select_cols)
        else:
            process_program(program_name, nofo_list, award_list, select_cols)
# Out:
# ---
# Pancreatic Adenocarcinoma Stromal Reprograming ConSortium (PSRC/PASSCODE)
# NOFO Results: RFA-CA-21-041 (1/1): {'search_id': 'dcZHO0I8r0iXdqU3Euiv3g', 'total': 6, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/dcZHO0I8r0iXdqU3Euiv3g/projects'}}
# NOFO Results: RFA-CA-21-042 (1/1): {'search_id': 'AQtzkxzxDkyUqvDBBxTYtw', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/AQtzkxzxDkyUqvDBBxTYtw/projects'}}
# Award Results: 1 U24 CA274274-01 (1/1): {'search_id': 'DSlmuUgSH0yOZPE9meEhLA', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/DSlmuUgSH0yOZPE9meEhLA/projects'}}
# ---
# Oncology Models Forum (U24)
# NOFO Results: PAR14-239 (1/1): {'search_id': 'RxqbxxRQ2kaFjd_1t8yc9Q', 'total': 5, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/RxqbxxRQ2kaFjd_1t8yc9Q/projects'}}
# NOFO Results: PAR-16-059 (1/1): {'search_id': 'IJkwgPaWW0epXmZc6HJ71A', 'total': 25, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/IJkwgPaWW0epXmZc6HJ71A/projects'}}
# NOFO Results: PAR-17-245 (1/1): {'search_id': '7WF6tPWN1kS1iWGAJSl3pw', 'total': 139, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/7WF6tPWN1kS1iWGAJSl3pw/projects'}}
# NOFO Results: PAR-20-131 (1/1): {'search_id': 'tWjWNteQFUq4GvsalTF1QQ', 'total': 46, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/tWjWNteQFUq4GvsalTF1QQ/projects'}}
# Award Results: 5U24CA195858 (1/1): {'search_id': 'YX0pkL30RkeevJQ3e77xkQ', 'total': 4, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/YX0pkL30RkeevJQ3e77xkQ/projects'}}
# ---
# Pediatric Preclinical in Vivo Testing (PIVOT)
# NOFO Results: RFA-CA-20-034 (1/1): {'search_id': 'njAYLbAo2E2cbkzzLj7AAQ', 'total': 21, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/njAYLbAo2E2cbkzzLj7AAQ/projects'}}
# NOFO Results: RFA-CA-14-018 (1/1): {'search_id': 'slxzrkXhB0m_D_ekjYlxvQ', 'total': 25, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/slxzrkXhB0m_D_ekjYlxvQ/projects'}}
# NOFO Results: RFA-CA-20-041 (1/1): {'search_id': 'PZcdeMhEME2f-vUyj8Beog', 'total': 3, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/PZcdeMhEME2f-vUyj8Beog/projects'}}
# Award Results: U24CA263963 (1/1): {'search_id': 'ocHTLJKC6EC2eyIAQHMbvw', 'total': 3, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/ocHTLJKC6EC2eyIAQHMbvw/projects'}}
# ---
# Cancer Immunologic Data Commons
# NOFO Results: RFA-CA-17-006 (1/1): {'search_id': 'DFSRI-bKhUm9jWVrDjAX2w', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/DFSRI-bKhUm9jWVrDjAX2w/projects'}}
# NOFO Results: RFA-CA-22-038 (1/1): {'search_id': 'fwMz4RID-E2ASniV0uLG4Q', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/fwMz4RID-E2ASniV0uLG4Q/projects'}}
# Award Results: 1U24CA224316 (1/1): {'search_id': 'Wp-PUImegUGzSQEp6ldQZw', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/Wp-PUImegUGzSQEp6ldQZw/projects'}}
# ---
# CANCER IMMUNE MONITORING AND ANALYSIS CENTERS
# NOFO Results: RFA-CA-17-005 (1/1): {'search_id': 'rLrbsfm7KUChUSOfwDDdng', 'total': 4, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/rLrbsfm7KUChUSOfwDDdng/projects'}}
# NOFO Results: RFA-CA-22-038 (1/1): {'search_id': 'VFMPAwoL5EWExDLSBNLGhg', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/VFMPAwoL5EWExDLSBNLGhg/projects'}}
# ---
# Cellular Cancer Biology Imaging Research
# NOFO Results: RFA-CA-21-002 (1/1): {'search_id': 'MOdp6jBonkyQQnCexlmP8w', 'total': 8, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/MOdp6jBonkyQQnCexlmP8w/projects'}}
# ---
# Barrett’s Esophagus Translational Research Network (BETRNet)
# NOFO Results: RFA-CA-16-007 (1/1): {'search_id': 'FHLApOO1eU2TVcgUN6533g', 'total': 5, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/FHLApOO1eU2TVcgUN6533g/projects'}}
# NOFO Results: RFA-CA-16-006 (1/1): {'search_id': 'hZ7JiHn06UyF-Pva02kmoQ', 'total': 16, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/hZ7JiHn06UyF-Pva02kmoQ/projects'}}
# NOFO Results: RFA-CA-10-014 (1/1): {'search_id': 'YT189Zu6dkGSiUy30SiLJw', 'total': 19, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/YT189Zu6dkGSiUy30SiLJw/projects'}}
# ---
# Fusion Oncoproteins in Childhood Cancers (FusOnc2)
# NOFO Results: RFA-CA-17-049 (1/1): {'search_id': 'A-8OmLnehEyatt4M8yB4eg', 'total': 4, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/A-8OmLnehEyatt4M8yB4eg/projects'}}
# NOFO Results: RFA-CA-19-016 (1/1): {'search_id': 'eqr6rcIaakKIag0kVQVXFw', 'total': 12, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/eqr6rcIaakKIag0kVQVXFw/projects'}}
# ---
# The Early Detection Research Network (EDRN)
# NOFO Results: CA-14-017 (1/1): {'search_id': 'qLPnaEfc00eThnZANg3bnA', 'total': 8, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/qLPnaEfc00eThnZANg3bnA/projects'}}
# NOFO Results: CA-21-034 (1/1): {'search_id': 'dnjo6SNMEkui3gOe6wVbkw', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/dnjo6SNMEkui3gOe6wVbkw/projects'}}
# NOFO Results: CA-21-033 (1/1): {'search_id': 'qC-cVJHrC0yMx748TLQueA', 'total': 9, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/qC-cVJHrC0yMx748TLQueA/projects'}}
# NOFO Results: CA-21-035 (1/1): {'search_id': '0iXcJf358EWZ_OPrBy3iOg', 'total': 11, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/0iXcJf358EWZ_OPrBy3iOg/projects'}}
# NOFO Results: CA-14-015 (1/1): {'search_id': 'ICa3MJy2xEOpPXPz53F8Qw', 'total': 56, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/ICa3MJy2xEOpPXPz53F8Qw/projects'}}
# NOFO Results: CA-14-016 (1/1): {'search_id': '0Ej70op2-0uy69p5gckqWw', 'total': 12, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/0Ej70op2-0uy69p5gckqWw/projects'}}
# NOFO Results: CA-16-009 (1/1): {'search_id': '9es4L_BX4U-czAuccNzyQw', 'total': 49, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/9es4L_BX4U-czAuccNzyQw/projects'}}
# ---
# Cancer Prevention-Interception Targeted Agent Discovery Program
# NOFO Results: RFA-CA-21-038 (1/1): {'search_id': '5yHWdzo6fU2-Bg2UuBZm4g', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/5yHWdzo6fU2-Bg2UuBZm4g/projects'}}
# NOFO Results: RFA-CA-22-055 (1/1): {'search_id': '2GKPJsNq3UyNVg34JkBeKQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/2GKPJsNq3UyNVg34JkBeKQ/projects'}}
# NOFO Results: RFA-CA-21-039 (1/1): {'search_id': 'Wz7B4nW9Fk-4aGBtbfxXuA', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/Wz7B4nW9Fk-4aGBtbfxXuA/projects'}}
# ---
#  Small Cell Lung Cancer (SCLC) Consortium
# NOFO Results: PAR21-346 (1/1): {'search_id': 'exAvhMW0wkyrQkWEfpFCeQ', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/exAvhMW0wkyrQkWEfpFCeQ/projects'}}
# NOFO Results: PAR-16-049 (1/1): {'search_id': 'eDmPztGxuEyDI8lbS7x9XQ', 'total': 46, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/eDmPztGxuEyDI8lbS7x9XQ/projects'}}
# NOFO Results: PAR-16-050 (1/1): {'search_id': 'lW9TSJ1iBEKVfnggHj_x-A', 'total': 5, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/lW9TSJ1iBEKVfnggHj_x-A/projects'}}
# NOFO Results: PAR-16-051 (1/1): {'search_id': 'xHSEXkoXpkGAnMDri8nUfg', 'total': 30, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/xHSEXkoXpkGAnMDri8nUfg/projects'}}
# NOFO Results: PAR-19-361 (1/1): {'search_id': 'ty21ns5gGUiBSYLN1bM3Dg', 'total': 10, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/ty21ns5gGUiBSYLN1bM3Dg/projects'}}
# ---
# Acquired Resistance to Therapy Network (ARTNet)
# NOFO Results: RFA-CA-21-052 (1/1): {'search_id': '5MlSIoj5I0uUn1SeixuM3g', 'total': 5, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/5MlSIoj5I0uUn1SeixuM3g/projects'}}
# NOFO Results: RFA-CA-21-053 (1/1): {'search_id': 'nU2P-Z_slkCGkgyU-4svNQ', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/nU2P-Z_slkCGkgyU-4svNQ/projects'}}
# ---
# All of Us
# NOFO Results: HG21-041 (1/1): {'search_id': '9ZY7WMfzpEex4huO5wThbw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/9ZY7WMfzpEex4huO5wThbw/projects'}}
# NOFO Results: LM21-002 (1/1): {'search_id': 'KYc3XclapU-KdhlbUa4gNA', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/KYc3XclapU-KdhlbUa4gNA/projects'}}
# NOFO Results: MH22-200 (1/1): {'search_id': '_lzzoq2UHk-JW9_hIrXCKg', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/_lzzoq2UHk-JW9_hIrXCKg/projects'}}
# NOFO Results: OD21-144 (1/1): {'search_id': 'Hw3Yh2T9y0iK_mSnMFg6wQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/Hw3Yh2T9y0iK_mSnMFg6wQ/projects'}}
# NOFO Results: OD22-150 (1/1): {'search_id': 'TqhbqyvhaEeD663uPCxc0Q', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/TqhbqyvhaEeD663uPCxc0Q/projects'}}
# NOFO Results: OD22-153 (1/1): {'search_id': '-VoRoRWhwk6EMH8gJ7eOvg', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/-VoRoRWhwk6EMH8gJ7eOvg/projects'}}
# NOFO Results: OTA17-002 (1/1): {'search_id': 'x9yJQKtr0UCN4i_987kKuw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/x9yJQKtr0UCN4i_987kKuw/projects'}}
# NOFO Results: OTA18-001 (1/1): {'search_id': 'OBf4wsd270qNZm5fvSy1Aw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/OBf4wsd270qNZm5fvSy1Aw/projects'}}
# NOFO Results: OTA19-002 (1/1): {'search_id': 'd-eN6bw5SkqNLFAcGxhzTQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/d-eN6bw5SkqNLFAcGxhzTQ/projects'}}
# NOFO Results: OTA19-003 (1/1): {'search_id': '9cb1s-fpskGMyVGvVcZj4A', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/9cb1s-fpskGMyVGvVcZj4A/projects'}}
# NOFO Results: OTA19-004 (1/1): {'search_id': 'w4NWTJbWHk26cafNigdFuQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/w4NWTJbWHk26cafNigdFuQ/projects'}}
# NOFO Results: OTA20-001 (1/1): {'search_id': 'ebu8OBEuW0Sc5arkNI-GvQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/ebu8OBEuW0Sc5arkNI-GvQ/projects'}}
# NOFO Results: OTA20-009 (1/1): {'search_id': 'veq-0TpUiEyujV-x-f-yKg', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/veq-0TpUiEyujV-x-f-yKg/projects'}}
# NOFO Results: OTA22-006 (1/1): {'search_id': 'ykF_5N8b5kuPmy3-DWH6MA', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/ykF_5N8b5kuPmy3-DWH6MA/projects'}}
# NOFO Results: OTA23-001 (1/1): {'search_id': '9o5510J5NUi1CregxCKNDw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/9o5510J5NUi1CregxCKNDw/projects'}}
# NOFO Results: OTA23-003 (1/1): {'search_id': 'VnjvuHcX10Sk_Bc5PkU-3Q', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/VnjvuHcX10Sk_Bc5PkU-3Q/projects'}}
# NOFO Results: A17-446 (1/1): {'search_id': 'CrSuTbITikGJytYLM0Epyw', 'total': 4, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/CrSuTbITikGJytYLM0Epyw/projects'}}
# NOFO Results: PA18-91 (1/1): {'search_id': 'An13j6M8wku8b8WU0FB4aQ', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/An13j6M8wku8b8WU0FB4aQ/projects'}}
# NOFO Results: PA20-145 (1/1): {'search_id': 'XrVxj2VE50W-9pz8nMLwjg', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/XrVxj2VE50W-9pz8nMLwjg/projects'}}
# NOFO Results: PA20-185 (1/6): {'search_id': '88r8wSOaokOKTXlWntK-Sg', 'total': 2627, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/88r8wSOaokOKTXlWntK-Sg/projects'}}
# NOFO Results: PA20-185 (2/6): {'search_id': 'Sverjix89U6m_A49QAHQvw', 'total': 2627, 'offset': 500, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/Sverjix89U6m_A49QAHQvw/projects'}}
# NOFO Results: PA20-185 (3/6): {'search_id': 's4NEnGrUfEiKFIcUmhDHWA', 'total': 2627, 'offset': 1000, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/s4NEnGrUfEiKFIcUmhDHWA/projects'}}
# NOFO Results: PA20-185 (4/6): {'search_id': '4tWjjXqOD0qcEO1Lr4-TYQ', 'total': 2627, 'offset': 1500, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/4tWjjXqOD0qcEO1Lr4-TYQ/projects'}}
# NOFO Results: PA20-185 (5/6): {'search_id': 'zP6pbp7vb0mnuGkJbw5Haw', 'total': 2627, 'offset': 2000, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/zP6pbp7vb0mnuGkJbw5Haw/projects'}}
# NOFO Results: PA20-185 (6/6): {'search_id': 'rFbW8-OX8Ua37AbbQbwBmw', 'total': 2627, 'offset': 2500, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/rFbW8-OX8Ua37AbbQbwBmw/projects'}}
# NOFO Results: PA20-272 (1/2): {'search_id': '7LnyVxpFL0GqPjJzIN9tFw', 'total': 543, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/7LnyVxpFL0GqPjJzIN9tFw/projects'}}
# NOFO Results: PA20-272 (2/2): {'search_id': '4KTxsqamzU6BNgoC9iUSJA', 'total': 543, 'offset': 500, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/4KTxsqamzU6BNgoC9iUSJA/projects'}}
# NOFO Results: PAR20-150 (1/1): {'search_id': 'wcuUxDqJkkOzIZY4XrMaOA', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/wcuUxDqJkkOzIZY4XrMaOA/projects'}}
# NOFO Results: PM23-001 (1/1): {'search_id': '2DslerGMVEODc3YMMGHAGg', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/2DslerGMVEODc3YMMGHAGg/projects'}}
# NOFO Results: PM23-002 (1/1): {'search_id': 'QsCwBMu97UySDr4yHuGEtw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/QsCwBMu97UySDr4yHuGEtw/projects'}}
# NOFO Results: RM21-002 (1/1): {'search_id': 'QBl8c_MRDEurfepY2ntCTA', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/QBl8c_MRDEurfepY2ntCTA/projects'}}
# NOFO Results: RM21-003 (1/1): {'search_id': '5La7ulQk2kCy600dFZU74g', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/5La7ulQk2kCy600dFZU74g/projects'}}
# NOFO Results: RM21-005 (1/1): {'search_id': '6NZYRNRdW0a4kcE0G3epRQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/6NZYRNRdW0a4kcE0G3epRQ/projects'}}
# NOFO Results: RM21-006 (1/1): {'search_id': 'rgyfeY1LF02VMhwenPp02w', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/rgyfeY1LF02VMhwenPp02w/projects'}}
# NOFO Results: RM21-016 (1/1): {'search_id': 'mdaDXptyvkyduQHKbgpJQw', 'total': 8, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/mdaDXptyvkyduQHKbgpJQw/projects'}}
# NOFO Results: SM18-009 (1/1): {'search_id': '4SP_FkRVDUW2Q6vMgBQi7A', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/4SP_FkRVDUW2Q6vMgBQi7A/projects'}}
# NOFO Results: SM21-007 (1/1): {'search_id': 'oHpo-3_cgUmkx93SthTEjg', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/oHpo-3_cgUmkx93SthTEjg/projects'}}
# NOFO Results: SP20-002 (1/1): {'search_id': 'NVNxe-zmSECif0jJ10ad0w', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/NVNxe-zmSECif0jJ10ad0w/projects'}}
# ---
# Childhood Cancer Survivor Study
# NOFO Results: RFA-CA-20-052 (1/1): {'search_id': 'BR86Be8IJEe9-KWHaCgN7g', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/BR86Be8IJEe9-KWHaCgN7g/projects'}}
# NOFO Results: RFA-CA15-502 (1/1): {'search_id': 'KugcTscJqEasUvo6kEzrvw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/KugcTscJqEasUvo6kEzrvw/projects'}}
# Award Results: 2U24CA055727-28 (1/1): {'search_id': '2yPFgZ47B0q-z4B7adR4Hg', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/2yPFgZ47B0q-z4B7adR4Hg/projects'}}
# Award Results: 3U24CA055727-26S1 (1/1): {'search_id': 'bkwWuYodJ0GXJ39Xtz6ZMA', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/bkwWuYodJ0GXJ39Xtz6ZMA/projects'}}
# ---
# The Adjuvant Lung Cancer Enrichment Marker Identification and Sequencing Trials (ALCHEMIST)
# Award Results: U10CA180821 (1/1): {'search_id': 'h7PZb2Hf_0yZLkkf6aDMrw', 'total': 35, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/h7PZb2Hf_0yZLkkf6aDMrw/projects'}}
# Award Results: U10CA180830 (1/1): {'search_id': 'w89Rgk7LrUmotLZ7CYl5vA', 'total': 5, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/w89Rgk7LrUmotLZ7CYl5vA/projects'}}
# Award Results: U10CA031946 (1/1): {'search_id': 'S8Zf74ChT02VYFBxWDdjOA', 'total': 66, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/S8Zf74ChT02VYFBxWDdjOA/projects'}}
# ---
# PaCMEN
# NOFO Results: RFA-CA-17-015 (1/1): {'search_id': 'oOVK_RzpckW5UHz1xwI6ug', 'total': 16, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/oOVK_RzpckW5UHz1xwI6ug/projects'}}
# NOFO Results: RFA-CA-17-016 (1/1): {'search_id': 'dDOyOm1XWUqUPRphqyIphA', 'total': 3, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/dDOyOm1XWUqUPRphqyIphA/projects'}}
# Award Results: U01CA224146 (1/1): {'search_id': 'q2ye5BFbSEu_xC6wd7Ybog', 'total': 3, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/q2ye5BFbSEu_xC6wd7Ybog/projects'}}
# Award Results: U01CA224193-01 (1/1): {'search_id': 'zLUXH1A1D06AQQodBMTyKQ', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/zLUXH1A1D06AQQodBMTyKQ/projects'}}
# Award Results: 4U01CA224348-02 (1/1): {'search_id': '5QlNwAujGkuOHqrKP-WTbA', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/5QlNwAujGkuOHqrKP-WTbA/projects'}}
# ---
# AIDS and Cancer Specimen Resource (ACSR)
# NOFO Results: RFA-CA-18-012 (1/1): {'search_id': 'af8HBZsn60-gPe9mAhZuVg', 'total': 4, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/af8HBZsn60-gPe9mAhZuVg/projects'}}
# Award Results: UM1CA181255 (1/1): {'search_id': 'LLHHY_lK_0mVDLjJgRSrzA', 'total': 10, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/LLHHY_lK_0mVDLjJgRSrzA/projects'}}
# ---
# SPORE in Bladder Cancer
# Award Results: P50CA221745 (1/1): {'search_id': 'MMIZcEtVkk2WIG066bAaig', 'total': 5, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/MMIZcEtVkk2WIG066bAaig/projects'}}
# ---
# SPORE: Targeted Therapies for Glioma
# Award Results: P50CA165962 (1/1): {'search_id': 'ju1WacrMM0SakKsNKh6HzQ', 'total': 13, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/ju1WacrMM0SakKsNKh6HzQ/projects'}}
# ---
# The Memorial Sloan Kettering Cancer Center SPORE in Leukemia
# Award Results: P50CA254838 (1/1): {'search_id': 'yIRS5MbQlkCzKdrHY4LWJw', 'total': 3, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/yIRS5MbQlkCzKdrHY4LWJw/projects'}}
# ---
# The University of Texas MD Anderson Cancer Center SPORE in Hepatocellular Carcinoma
# Award Results: P50CA217674 (1/1): {'search_id': 'I9UaQaWPzUW_hF37P8FRUg', 'total': 4, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/I9UaQaWPzUW_hF37P8FRUg/projects'}}
# ---
# Brain Tumor SPORE Grant
# Award Results: P50CA097257 (1/1): {'search_id': 'xCEo3CDsmkC65_FsuCEZdA', 'total': 26, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/xCEo3CDsmkC65_FsuCEZdA/projects'}}
# ---
# Vanderbilt-Ingram Cancer Center SPORE in Gastrointestinal Cancer
# Award Results: P50CA236733 (1/1): {'search_id': 'xRPeRAbOx0e3sUq-yMhy7A', 'total': 5, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/.reporter.nih.gov/search/xRPeRAbOx0e3sUq-yMhy7A/projects'}}
# ---
# ADMIRAL Study: Admixture analysis of acute lymphoblastic leukemia in African American children
# Award Results: R01CA239701 (1/1): {'search_id': 'rFNLfCj-oE-AYv7NHbhYxw', 'total': 4, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/rFNLfCj-oE-AYv7NHbhYxw/projects'}}
# ---
# SPORE in Myeloid Malignancies
# Award Results: P50CA206963 (1/1): {'search_id': 'PDSYOpytukuX8J9G4EG2Zw', 'total': 6, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/PDSYOpytukuX8J9G4EG2Zw/projects'}}
# ---
# Yale SPORE in Lung Cancer (YSILC): The Biology and Personalized Treatment of Lung Cancer
# Award Results: P50CA196530 (1/1): {'search_id': '3jLXtIbBYUW-CrD1V4ACFA', 'total': 10, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/3jLXtIbBYUW-CrD1V4ACFA/projects'}}
# ---
# Fred Hutchinson Cancer Research Center Lung SPORE
# Award Results: P50CA228944 (1/1): {'search_id': '3QuRgYbvjEiJUZ98tJhcxQ', 'total': 6, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/3QuRgYbvjEiJUZ98tJhcxQ/projects'}}

# %% [markdown]
# Success! Results will look good once the cleaning functions are properly added.
# First, let's clean and combine the nofo vs award api functions

# %%
def get_nih_reporter_grants(search_values:str, search_type:str, print_meta=False):
    """Get grants info for either NOFOs or Awards as specified.
    
    :param search_values: string of values to search, separated by semicolons

    :param search_type: type of search (e.g., 'nofo' or 'award')

    :param print_meta: boolean indicator. If True, print API gathering 
                        process results to console.
    """

    # Set the search field based on the search_type
    if search_type == 'nofo':
        search_field = "foa"
    elif search_type == 'award':
        search_field = "project_nums"
    else:
        raise ValueError("Invalid search type.")

    base_url = "https://api.reporter.nih.gov/v2/projects/search"
    grants_data = []

    for search_value in search_values:
        # Check for blank search values
        if not search_value:
            print(f"Blank {search_type} value encountered. Skipping.")
            continue

        # Set default values for params not likley to change
        LIMIT = 500
        MAX_ATTEMPTS = 5
        RETRY_TIME = 2

        # Set starting value for counters
        offset = 0
        page = 0
        attempts = 0

        # RePORTER API sets a max limit of 500 records per call.
        # Keep looping each call in "pages" until the number of records 
        # gathered reaches the total number of records available. 
        
        # Set a cap on the number of attempts at a failed call before 
        # moving on to the next award.
        while attempts < MAX_ATTEMPTS:
            # Set parameters for API call
            params = {
                "criteria": {
                    search_field: [search_value],
                    "exclude_subprojects": True,
                    "agencies": ["NCI"]
                },
                "limit": LIMIT,
                "offset": offset,
                "sort_field": "FiscalYear",
                "sort_order": "desc",
            }

            try: 
                # Define response details
                response = requests.post(base_url, 
                                        json=params, 
                                        headers={
                                            "accept": "application/json", 
                                            "Content-Type": "application/json"})

                # If response is good, get results
                if response.status_code == 200:
                    grants = response.json()
                    # Add API source indicator
                    for grant in grants['results']:
                        grant['api_source_search'] = f"{search_type}_{search_value}"
                    # Add grants to running list
                    grants_data.extend(grants['results'])

                    # Increase offset by limit to get next "page"
                    total_records = grants['meta']['total']
                    offset = offset + LIMIT
                    page = page + 1

                    # Print paginated partial optional metadata
                    # Consider replacing this with proper logging
                    if print_meta == True:
                        total_pages = max(ceil(total_records/LIMIT),1)
                        print(f"{search_type}: {search_value} "
                              f"{page}/{total_pages}): {grants['meta']}")

                    # Stop looping if offset has reached total record count
                    if offset >= total_records:
                        break

                # Handle 500 errors by retrying after 2 second delay
                elif response.status_code == 500:
                    attempts = attempts + 1
                    print(f"Received a 500 error for "
                          f"{search_type} '{search_value}'. "
                          f"Retrying after {RETRY_TIME} seconds. "
                          f"Attempt {attempts}/{MAX_ATTEMPTS}")
                    sleep(RETRY_TIME)
                else:
                    print(f"Error occurred while fetching grants for "
                          f"{search_type} '{search_value}': "
                          f"{response.status_code}")
                    break

            except requests.exceptions.RequestException as e:
                print(f"An error occurred while making the API call for "
                      f"{search_type} '{search_value}': {e}")
                break

    return grants_data

# %% [markdown]
# Rework the process_program to use the new get_nih_reporter_grants that combines nofos and award search

# %%
def process_program(program_name, nofo_list, award_list, select_cols):
    """Create grants TSVs for each key program."""

    # Get grants data using NIH RePORTER API for NOFOs and Awards
    nofo_grants_data = get_nih_reporter_grants(nofo_list, 'nofo', print_meta=True)
    award_grants_data = get_nih_reporter_grants(award_list, 'award', print_meta=True)

    # Combine data
    combined_grants_data = nofo_grants_data + award_grants_data

    # Create dataframe and clean grants data
    clean_grants = clean_grants_data(combined_grants_data, select_cols)

    # Export grants data as tsv for each program
    # EXPORT DISABLED TO AVOID CONFUSION
    # Use program names with only alphanumeric characters for filename
    # file_name = f"{''.join(filter(str.isalnum, program_name))}.csv"
    # clean_grants.to_csv(file_name, index=False)

# %%
for index, row in df_key_programs.iterrows():
    program_name = row['program_name']
    nofo_str = row['nofo']
    award_str = row['award']

    print(f"---\n{program_name}")

    if pd.isna(nofo_str) and pd.isna(award_str):
        print(f"No NOFOs or Awards defined. Skipping.")
    elif pd.isna(nofo_str):
        award_list = [x.strip() for x in award_str.split(';')]
        process_program(program_name, [], award_list, select_cols)
    elif pd.isna(award_str):
        nofo_list = [x.strip() for x in nofo_str.split(';')]
        process_program(program_name, nofo_list, [], select_cols)
    else:
        nofo_list = [x.strip() for x in nofo_str.split(';')]
        award_list = [x.strip() for x in award_str.split(';')]
        process_program(program_name, nofo_list, award_list, select_cols)
# Out:
# ---
# Pancreatic Adenocarcinoma Stromal Reprograming ConSortium (PSRC/PASSCODE)
# nofo: RFA-CA-21-041 1/1): {'search_id': 'X7dvS4WqO06mT-I5XBDLWg', 'total': 6, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/X7dvS4WqO06mT-I5XBDLWg/projects'}}
# nofo: RFA-CA-21-042 1/1): {'search_id': 'jJdCM8xcrE6gmTroy1l0Ng', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/jJdCM8xcrE6gmTroy1l0Ng/projects'}}
# award: 1 U24 CA274274-01 1/1): {'search_id': 'KIVKsorZW0WzmI9Bvp1UNA', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/KIVKsorZW0WzmI9Bvp1UNA/projects'}}
# ---
# Oncology Models Forum (U24)
# nofo: PAR14-239 1/1): {'search_id': 'mcqaPlAZqE2YONF1Y7jC-A', 'total': 5, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/mcqaPlAZqE2YONF1Y7jC-A/projects'}}
# nofo: PAR-16-059 1/1): {'search_id': 'xYcrQLHCZEuotaxNaFTdxA', 'total': 25, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/xYcrQLHCZEuotaxNaFTdxA/projects'}}
# nofo: PAR-17-245 1/1): {'search_id': 'unreq6iQMkSpb-3_PzWpqw', 'total': 139, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/unreq6iQMkSpb-3_PzWpqw/projects'}}
# nofo: PAR-20-131 1/1): {'search_id': 'dtsvFF6WtUK_O8BNrR-dRQ', 'total': 46, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/dtsvFF6WtUK_O8BNrR-dRQ/projects'}}
# award: 5U24CA195858 1/1): {'search_id': 'VVLTzolaakSkjhJjManLKw', 'total': 4, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/VVLTzolaakSkjhJjManLKw/projects'}}
# ---
# Pediatric Preclinical in Vivo Testing (PIVOT)
# nofo: RFA-CA-20-034 1/1): {'search_id': 'PTr0gskKT0KtLNWBS1sJ5g', 'total': 21, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/PTr0gskKT0KtLNWBS1sJ5g/projects'}}
# nofo: RFA-CA-14-018 1/1): {'search_id': '8NQhyQs3g0aRgTvRXtp6YA', 'total': 25, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/8NQhyQs3g0aRgTvRXtp6YA/projects'}}
# nofo: RFA-CA-20-041 1/1): {'search_id': 'vMlNwbv9gkGK5Rbb3N3m0g', 'total': 3, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/vMlNwbv9gkGK5Rbb3N3m0g/projects'}}
# award: U24CA263963 1/1): {'search_id': 'WfO-3ZQCBEe5sAJaX6GNig', 'total': 3, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/WfO-3ZQCBEe5sAJaX6GNig/projects'}}
# ---
# Cancer Immunologic Data Commons
# nofo: RFA-CA-17-006 1/1): {'search_id': '-OLZRkKgB0Cib9o1lAFkiw', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/-OLZRkKgB0Cib9o1lAFkiw/projects'}}
# nofo: RFA-CA-22-038 1/1): {'search_id': '0z3JtY-k1UKxoqLFGhf4SA', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/0z3JtY-k1UKxoqLFGhf4SA/projects'}}
# award: 1U24CA224316 1/1): {'search_id': '6CpUjJ1o9kqX3z88Mh-Udw', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/6CpUjJ1o9kqX3z88Mh-Udw/projects'}}
# ---
# CANCER IMMUNE MONITORING AND ANALYSIS CENTERS
# nofo: RFA-CA-17-005 1/1): {'search_id': 'fsqJQTlD0UWYK8eWRuR5ww', 'total': 4, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/fsqJQTlD0UWYK8eWRuR5ww/projects'}}
# nofo: RFA-CA-22-038 1/1): {'search_id': 'FfdG3fCzFE66PlF_r4TXdA', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/FfdG3fCzFE66PlF_r4TXdA/projects'}}
# ---
# Cellular Cancer Biology Imaging Research
# nofo: RFA-CA-21-002 1/1): {'search_id': '4u-cux009kechRHcWrl1Vw', 'total': 8, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/4u-cux009kechRHcWrl1Vw/projects'}}
# ---
# Barrett’s Esophagus Translational Research Network (BETRNet)
# nofo: RFA-CA-16-007 1/1): {'search_id': 'YJJiYq_E60C7QquipppKOw', 'total': 5, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/YJJiYq_E60C7QquipppKOw/projects'}}
# nofo: RFA-CA-16-006 1/1): {'search_id': 'XWulpY4vuU6MC3rIx1oC1w', 'total': 16, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/XWulpY4vuU6MC3rIx1oC1w/projects'}}
# nofo: RFA-CA-10-014 1/1): {'search_id': 'aO9UIRzqKEeEZHMtcw-_wA', 'total': 19, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/aO9UIRzqKEeEZHMtcw-_wA/projects'}}
# ---
# Fusion Oncoproteins in Childhood Cancers (FusOnc2)
# nofo: RFA-CA-17-049 1/1): {'search_id': 'JBKNG-Asc0q6M3583BZKLQ', 'total': 4, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/JBKNG-Asc0q6M3583BZKLQ/projects'}}
# nofo: RFA-CA-19-016 1/1): {'search_id': 'cJFwQljirk6bXH7LcHdC3Q', 'total': 12, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/cJFwQljirk6bXH7LcHdC3Q/projects'}}
# ---
# The Early Detection Research Network (EDRN)
# nofo: CA-14-017 1/1): {'search_id': 'bP7Vwc9uokGSkpBUn6ggPQ', 'total': 8, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/bP7Vwc9uokGSkpBUn6ggPQ/projects'}}
# nofo: CA-21-034 1/1): {'search_id': '1EKrcXQcwkWCbUgDft_7RA', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/1EKrcXQcwkWCbUgDft_7RA/projects'}}
# nofo: CA-21-033 1/1): {'search_id': 'Bb-l7dPrbEqp-ujLPFtDsw', 'total': 9, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/Bb-l7dPrbEqp-ujLPFtDsw/projects'}}
# nofo: CA-21-035 1/1): {'search_id': 'FGTBs7BI1ESvD7URoV8fgg', 'total': 11, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/FGTBs7BI1ESvD7URoV8fgg/projects'}}
# nofo: CA-14-015 1/1): {'search_id': '8fDYP7R2c0iiHUsJ70ZtYA', 'total': 56, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/8fDYP7R2c0iiHUsJ70ZtYA/projects'}}
# nofo: CA-14-016 1/1): {'search_id': 'sU8qjYZMS0SNn7H6GyQGkg', 'total': 12, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/sU8qjYZMS0SNn7H6GyQGkg/projects'}}
# nofo: CA-16-009 1/1): {'search_id': '07GJIhJXRUyYXDZb7coKjA', 'total': 49, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/07GJIhJXRUyYXDZb7coKjA/projects'}}
# ---
# Cancer Prevention-Interception Targeted Agent Discovery Program
# nofo: RFA-CA-21-038 1/1): {'search_id': 'zNdCHXCTpU-jIXfvQcpdaA', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/zNdCHXCTpU-jIXfvQcpdaA/projects'}}
# nofo: RFA-CA-22-055 1/1): {'search_id': '1PTdrEnPSka94mrzDDHWew', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/1PTdrEnPSka94mrzDDHWew/projects'}}
# nofo: RFA-CA-21-039 1/1): {'search_id': 'Qm2qiAsjA0uPMeyCxWWN6A', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/Qm2qiAsjA0uPMeyCxWWN6A/projects'}}
# ---
#  Small Cell Lung Cancer (SCLC) Consortium
# nofo: PAR21-346 1/1): {'search_id': 'bVa-TyF1vEaTTQynkvSrsA', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/bVa-TyF1vEaTTQynkvSrsA/projects'}}
# nofo: PAR-16-049 1/1): {'search_id': 'mAAAKjL4z0i3FbmUKqd2Cw', 'total': 46, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/mAAAKjL4z0i3FbmUKqd2Cw/projects'}}
# nofo: PAR-16-050 1/1): {'search_id': 'xKzqvzfmM0Ouq3kOoBHsBQ', 'total': 5, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/xKzqvzfmM0Ouq3kOoBHsBQ/projects'}}
# nofo: PAR-16-051 1/1): {'search_id': 'MzlwuhEF5EOz3vc0wEqzmw', 'total': 30, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/MzlwuhEF5EOz3vc0wEqzmw/projects'}}
# nofo: PAR-19-361 1/1): {'search_id': '303PLVY_4U6FEtopBpg-XQ', 'total': 10, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/303PLVY_4U6FEtopBpg-XQ/projects'}}
# ---
# Acquired Resistance to Therapy Network (ARTNet)
# nofo: RFA-CA-21-052 1/1): {'search_id': 'QR5WzW3PRkCg3r0d-DDVBQ', 'total': 5, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/QR5WzW3PRkCg3r0d-DDVBQ/projects'}}
# nofo: RFA-CA-21-053 1/1): {'search_id': 'MG4od88S5E6SpHx-oDLQPA', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/MG4od88S5E6SpHx-oDLQPA/projects'}}
# ---
# All of Us
# nofo: HG21-041 1/1): {'search_id': '0N3DA1kWkUifTD29dOapAw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/0N3DA1kWkUifTD29dOapAw/projects'}}
# nofo: LM21-002 1/1): {'search_id': 'okegzOjNfE6a4mh3Q426DA', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/okegzOjNfE6a4mh3Q426DA/projects'}}
# nofo: MH22-200 1/1): {'search_id': 'WwBvJ05ifUOUwqOZt8QPVQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/WwBvJ05ifUOUwqOZt8QPVQ/projects'}}
# nofo: OD21-144 1/1): {'search_id': '6F457PMb6ESiIpgftC4dEg', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/6F457PMb6ESiIpgftC4dEg/projects'}}
# nofo: OD22-150 1/1): {'search_id': '0yAIZu1o10qBlAgDd_vTzw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/0yAIZu1o10qBlAgDd_vTzw/projects'}}
# nofo: OD22-153 1/1): {'search_id': 'qwHl3yd5nEO6PHOHH-u4sw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/qwHl3yd5nEO6PHOHH-u4sw/projects'}}
# nofo: OTA17-002 1/1): {'search_id': 'yVtyET6WQUyRa194IOzerg', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/yVtyET6WQUyRa194IOzerg/projects'}}
# nofo: OTA18-001 1/1): {'search_id': 'T9xs_Aax0UuX12IRWs-Tyw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/T9xs_Aax0UuX12IRWs-Tyw/projects'}}
# nofo: OTA19-002 1/1): {'search_id': '1FJBKGWLN0O2nu_2vY-EVg', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/1FJBKGWLN0O2nu_2vY-EVg/projects'}}
# nofo: OTA19-003 1/1): {'search_id': '0L533T_DKU21LU2TKc_mYw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/0L533T_DKU21LU2TKc_mYw/projects'}}
# nofo: OTA19-004 1/1): {'search_id': 'MgKmSs5rM0OqFGNehibbUA', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/MgKmSs5rM0OqFGNehibbUA/projects'}}
# nofo: OTA20-001 1/1): {'search_id': '2D47kCe6Bk-ai5xsGIYhcQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/2D47kCe6Bk-ai5xsGIYhcQ/projects'}}
# nofo: OTA20-009 1/1): {'search_id': 'FxaS3gfwNUOPDrfG8Vhnhw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/FxaS3gfwNUOPDrfG8Vhnhw/projects'}}
# nofo: OTA22-006 1/1): {'search_id': '8WbErYqBN0ijMJIZaF6SVw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/8WbErYqBN0ijMJIZaF6SVw/projects'}}
# nofo: OTA23-001 1/1): {'search_id': 's_t1eVegCkmU8MGRhuCtlQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/s_t1eVegCkmU8MGRhuCtlQ/projects'}}
# nofo: OTA23-003 1/1): {'search_id': 'FEQoOQ-LWUKEBX_nbcau-Q', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/FEQoOQ-LWUKEBX_nbcau-Q/projects'}}
# nofo: A17-446 1/1): {'search_id': 'C97_QZEAZEqCZuAv5kxKVQ', 'total': 4, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/C97_QZEAZEqCZuAv5kxKVQ/projects'}}
# nofo: PA18-91 1/1): {'search_id': 'vCJ_VfYeB0inUH1-XE3dUQ', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/vCJ_VfYeB0inUH1-XE3dUQ/projects'}}
# nofo: PA20-145 1/1): {'search_id': 'nigzcHXLFESHq_zK3i2BEA', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/nigzcHXLFESHq_zK3i2BEA/projects'}}
# nofo: PA20-185 1/6): {'search_id': 'qQbSyVT25UumCwFKOt1x2g', 'total': 2627, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/qQbSyVT25UumCwFKOt1x2g/projects'}}
# nofo: PA20-185 2/6): {'search_id': 'qjQKkBxk9UKRnNTM1JmEGw', 'total': 2627, 'offset': 500, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/qjQKkBxk9UKRnNTM1JmEGw/projects'}}
# nofo: PA20-185 3/6): {'search_id': 'HFwMeTFh3kqFd7QaD-Mq3A', 'total': 2627, 'offset': 1000, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/HFwMeTFh3kqFd7QaD-Mq3A/projects'}}
# nofo: PA20-185 4/6): {'search_id': 'JOtAMwdZRECBPMadK2Ccjg', 'total': 2627, 'offset': 1500, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/JOtAMwdZRECBPMadK2Ccjg/projects'}}
# nofo: PA20-185 5/6): {'search_id': 'kPlEF0VDuUqWinrmlUebRg', 'total': 2627, 'offset': 2000, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/kPlEF0VDuUqWinrmlUebRg/projects'}}
# nofo: PA20-185 6/6): {'search_id': 'VaAYTisk0UeKH_jI8wSPdQ', 'total': 2627, 'offset': 2500, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/VaAYTisk0UeKH_jI8wSPdQ/projects'}}
# nofo: PA20-272 1/2): {'search_id': 'YzLOtZMpwUWt2DkxD7YoGg', 'total': 543, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/YzLOtZMpwUWt2DkxD7YoGg/projects'}}
# nofo: PA20-272 2/2): {'search_id': '8PBLe1NSw0-fQdjbFOvyQQ', 'total': 543, 'offset': 500, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/8PBLe1NSw0-fQdjbFOvyQQ/projects'}}
# nofo: PAR20-150 1/1): {'search_id': 'COfi3B6X5EGN7VFUwItkfQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/COfi3B6X5EGN7VFUwItkfQ/projects'}}
# nofo: PM23-001 1/1): {'search_id': '7rrFAHLkA0qPvoug7cVH8g', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/7rrFAHLkA0qPvoug7cVH8g/projects'}}
# nofo: PM23-002 1/1): {'search_id': '10CwrAgNFkiQKo_RUTJxjw', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/10CwrAgNFkiQKo_RUTJxjw/projects'}}
# nofo: RM21-002 1/1): {'search_id': 'VJl_zckeaEOiZ6Ek5HA9-A', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/VJl_zckeaEOiZ6Ek5HA9-A/projects'}}
# nofo: RM21-003 1/1): {'search_id': 'w8ub14jTOEim6OHy-gI2Bg', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/w8ub14jTOEim6OHy-gI2Bg/projects'}}
# nofo: RM21-005 1/1): {'search_id': '5r2K8nVI2kqjvrkpIr1ztA', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/5r2K8nVI2kqjvrkpIr1ztA/projects'}}
# nofo: RM21-006 1/1): {'search_id': 'P_PKfr4BQkeRiD8rNK9GkQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/P_PKfr4BQkeRiD8rNK9GkQ/projects'}}
# nofo: RM21-016 1/1): {'search_id': '5s19yKJeq0CVWwq6LT-WHQ', 'total': 8, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/5s19yKJeq0CVWwq6LT-WHQ/projects'}}
# nofo: SM18-009 1/1): {'search_id': '2VvpXG_AjU261NNLmCdLbQ', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/2VvpXG_AjU261NNLmCdLbQ/projects'}}
# nofo: SM21-007 1/1): {'search_id': 'tc_o9Tr0RUuugAc0cgqD5w', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/tc_o9Tr0RUuugAc0cgqD5w/projects'}}
# nofo: SP20-002 1/1): {'search_id': '5avUjJUaTkqaP_RT2IyjJg', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/5avUjJUaTkqaP_RT2IyjJg/projects'}}
# ---
# Childhood Cancer Survivor Study
# nofo: RFA-CA-20-052 1/1): {'search_id': 'LFAXS3TLHEy6wcUgIZ-cnQ', 'total': 2, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/LFAXS3TLHEy6wcUgIZ-cnQ/projects'}}
# nofo: RFA-CA15-502 1/1): {'search_id': '0qjHO9psB0iCeqBCsK3cGg', 'total': 0, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/0qjHO9psB0iCeqBCsK3cGg/projects'}}
# award: 2U24CA055727-28 1/1): {'search_id': 'FLgB2mkyqU-Qw6j4_5uXpw', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/FLgB2mkyqU-Qw6j4_5uXpw/projects'}}
# award: 3U24CA055727-26S1 1/1): {'search_id': 'C-ETdmpmCUq2hZh8xLtrlA', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/C-ETdmpmCUq2hZh8xLtrlA/projects'}}
# ---
# The Adjuvant Lung Cancer Enrichment Marker Identification and Sequencing Trials (ALCHEMIST)
# award: U10CA180821 1/1): {'search_id': '8yZQ2_WJjkSGS656oulVWQ', 'total': 35, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/8yZQ2_WJjkSGS656oulVWQ/projects'}}
# award: U10CA180830 1/1): {'search_id': 'lgKCJKRXokCcCjA6igDgzQ', 'total': 5, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/lgKCJKRXokCcCjA6igDgzQ/projects'}}
# award: U10CA031946 1/1): {'search_id': 'QJGcgHIM9EGhgWaNYJJXtg', 'total': 66, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/QJGcgHIM9EGhgWaNYJJXtg/projects'}}
# ---
# PaCMEN
# nofo: RFA-CA-17-015 1/1): {'search_id': 'zmuetfPndUWbuLXwiAAMPg', 'total': 16, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/zmuetfPndUWbuLXwiAAMPg/projects'}}
# nofo: RFA-CA-17-016 1/1): {'search_id': 'EvSgeXzSskWGG3GeZkZu5w', 'total': 3, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/EvSgeXzSskWGG3GeZkZu5w/projects'}}
# award: U01CA224146 1/1): {'search_id': 'ueXvoxAwNEWIxJCfBntPgQ', 'total': 3, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/ueXvoxAwNEWIxJCfBntPgQ/projects'}}
# award: U01CA224193-01 1/1): {'search_id': '0V4DlHcidUOLyXHDlHpPnA', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/0V4DlHcidUOLyXHDlHpPnA/projects'}}
# award: 4U01CA224348-02 1/1): {'search_id': 'DDyF0GMpC0a_fShN_hl5hw', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/DDyF0GMpC0a_fShN_hl5hw/projects'}}
# ---
# AIDS and Cancer Specimen Resource (ACSR)
# nofo: RFA-CA-18-012 1/1): {'search_id': 'DoIx2BQIykG_LXNiJ0WpOA', 'total': 4, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': False, 'properties': {'URL': 'https:/reporter.nih.gov/search/DoIx2BQIykG_LXNiJ0WpOA/projects'}}
# award: UM1CA181255 1/1): {'search_id': 'WzdOBTOPUE6oav3R6gXCpQ', 'total': 10, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/WzdOBTOPUE6oav3R6gXCpQ/projects'}}
# ---
# SPORE in Bladder Cancer
# award: P50CA221745 1/1): {'search_id': 'DDq9wutTI0aPUc4Q5FULdw', 'total': 5, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/DDq9wutTI0aPUc4Q5FULdw/projects'}}
# ---
# SPORE: Targeted Therapies for Glioma
# award: P50CA165962 1/1): {'search_id': 'YrfN-KzDrEG-imozuV02Cg', 'total': 13, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/YrfN-KzDrEG-imozuV02Cg/projects'}}
# ---
# The Memorial Sloan Kettering Cancer Center SPORE in Leukemia
# award: P50CA254838 1/1): {'search_id': 'yRjnS-FCk0KsrfhruEu9Ng', 'total': 3, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/yRjnS-FCk0KsrfhruEu9Ng/projects'}}
# ---
# The University of Texas MD Anderson Cancer Center SPORE in Hepatocellular Carcinoma
# award: P50CA217674 1/1): {'search_id': 'kEdagQiOTEiXy7u-MfsfTw', 'total': 4, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/kEdagQiOTEiXy7u-MfsfTw/projects'}}
# ---
# Brain Tumor SPORE Grant
# award: P50CA097257 1/1): {'search_id': 'KPuShDW3_kW4PmAy6UZBHw', 'total': 26, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/KPuShDW3_kW4PmAy6UZBHw/projects'}}
# ---
# Vanderbilt-Ingram Cancer Center SPORE in Gastrointestinal Cancer
# award: P50CA236733 1/1): {'search_id': 'hnw68leOhESXtJjctx6SIg', 'total': 5, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/hnw68leOhESXtJjctx6SIg/projects'}}
# ---
# ADMIRAL Study: Admixture analysis of acute lymphoblastic leukemia in African American children
# award: R01CA239701 1/1): {'search_id': 'LbU3KCjToE6w7lyF_bVV6Q', 'total': 4, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/LbU3KCjToE6w7lyF_bVV6Q/projects'}}
# ---
# SPORE in Myeloid Malignancies
# award: P50CA206963 1/1): {'search_id': 'XcDdogj01ESM5S-DiE_xJw', 'total': 6, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/XcDdogj01ESM5S-DiE_xJw/projects'}}
# ---
# Yale SPORE in Lung Cancer (YSILC): The Biology and Personalized Treatment of Lung Cancer
# award: P50CA196530 1/1): {'search_id': '8CnUK5J5tkmhgHM2eMV7Tg', 'total': 10, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/8CnUK5J5tkmhgHM2eMV7Tg/projects'}}
# ---
# Fred Hutchinson Cancer Research Center Lung SPORE
# award: P50CA228944 1/1): {'search_id': '0Oz83LpgrkyXtcN1SJijzA', 'total': 6, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/0Oz83LpgrkyXtcN1SJijzA/projects'}}

# %%
# Rework the string-to-list conversion to reduce redundant redundancy
for index, row in df_key_programs.iterrows():
    program_name = row['program_name']
    nofo_str = row['nofo']
    award_str = row['award']

    print(f"---\n{program_name}")
    if isinstance(award_str, str): 
        award_list = [x.strip() for x in award_str.split(';')]
    else: award_list = []
    if isinstance(nofo_str, str): 
        nofo_list = [x.strip() for x in nofo_str.split(';')]
    else: nofo_list = []

    print(award_list)
    print(nofo_list)
# Out:
# ---
# Pancreatic Adenocarcinoma Stromal Reprograming ConSortium (PSRC/PASSCODE)
# ['1 U24 CA274274-01']
# ['RFA-CA-21-041', 'RFA-CA-21-042']
# ---
# Oncology Models Forum (U24)
# ['5U24CA195858']
# ['PAR14-239', 'PAR-16-059', 'PAR-17-245', 'PAR-20-131']
# ---
# Pediatric Preclinical in Vivo Testing (PIVOT)
# ['U24CA263963']
# ['RFA-CA-20-034', 'RFA-CA-14-018', 'RFA-CA-20-041']
# ---
# Cancer Immunologic Data Commons
# ['1U24CA224316']
# ['RFA-CA-17-006', 'RFA-CA-22-038']
# ---
# CANCER IMMUNE MONITORING AND ANALYSIS CENTERS
# []
# ['RFA-CA-17-005', 'RFA-CA-22-038']
# ---
# Cellular Cancer Biology Imaging Research
# []
# ['RFA-CA-21-002']
# ---
# Barrett’s Esophagus Translational Research Network (BETRNet)
# []
# ['RFA-CA-16-007', 'RFA-CA-16-006', 'RFA-CA-10-014']
# ---
# Fusion Oncoproteins in Childhood Cancers (FusOnc2)
# []
# ['RFA-CA-17-049', 'RFA-CA-19-016']
# ---
# The Early Detection Research Network (EDRN)
# []
# ['CA-14-017', 'CA-21-034', 'CA-21-033', 'CA-21-035', 'CA-14-015', 'CA-14-016', 'CA-16-009']
# ---
# Cancer Prevention-Interception Targeted Agent Discovery Program
# []
# ['RFA-CA-21-038', 'RFA-CA-22-055', 'RFA-CA-21-039']
# ---
#  Small Cell Lung Cancer (SCLC) Consortium
# []
# ['PAR21-346', 'PAR-16-049', 'PAR-16-050', 'PAR-16-051', 'PAR-19-361']
# ---
# Acquired Resistance to Therapy Network (ARTNet)
# []
# ['RFA-CA-21-052', 'RFA-CA-21-053']
# ---
# All of Us
# []
# ['HG21-041', 'LM21-002', 'MH22-200', 'OD21-144', 'OD22-150', 'OD22-153', 'OTA17-002', 'OTA18-001', 'OTA19-002', 'OTA19-003', 'OTA19-004', 'OTA20-001', 'OTA20-009', 'OTA22-006', 'OTA23-001', 'OTA23-003', 'A17-446', 'PA18-91', 'PA20-145', 'PA20-185', 'PA20-272', 'PAR20-150', 'PM23-001', 'PM23-002', 'RM21-002', 'RM21-003', 'RM21-005', 'RM21-006', 'RM21-016', 'SM18-009', 'SM21-007', 'SP20-002']
# ---
# Childhood Cancer Survivor Study
# ['2U24CA055727-28', '3U24CA055727-26S1']
# ['RFA-CA-20-052', 'RFA-CA15-502']
# ---
# The Adjuvant Lung Cancer Enrichment Marker Identification and Sequencing Trials (ALCHEMIST)
# ['U10CA180821', 'U10CA180830', 'U10CA031946']
# []
# ---
# PaCMEN
# ['U01CA224146', 'U01CA224193-01', '4U01CA224348-02']
# ['RFA-CA-17-015', 'RFA-CA-17-016']
# ---
# AIDS and Cancer Specimen Resource (ACSR)
# ['UM1CA181255']
# ['RFA-CA-18-012']
# ---
# SPORE in Bladder Cancer
# ['P50CA221745']
# []
# ---
# SPORE: Targeted Therapies for Glioma
# ['P50CA165962']
# []
# ---
# The Memorial Sloan Kettering Cancer Center SPORE in Leukemia
# ['P50CA254838']
# []
# ---
# The University of Texas MD Anderson Cancer Center SPORE in Hepatocellular Carcinoma
# ['P50CA217674']
# []
# ---
# Brain Tumor SPORE Grant
# ['P50CA097257']
# []
# ---
# Vanderbilt-Ingram Cancer Center SPORE in Gastrointestinal Cancer
# ['P50CA236733']
# []
# ---
# ADMIRAL Study: Admixture analysis of acute lymphoblastic leukemia in African American children
# ['R01CA239701']
# []
# ---
# SPORE in Myeloid Malignancies
# ['P50CA206963']
# []
# ---
# Yale SPORE in Lung Cancer (YSILC): The Biology and Personalized Treatment of Lung Cancer
# ['P50CA196530']
# []
# ---
# Fred Hutchinson Cancer Research Center Lung SPORE
# ['P50CA228944']
# []

# %% [markdown]
# Check that searching empty NOFOs or Awards were not resulting in unexpected results.

# %%
# Use pacmen awards and blank nofo
pac_str = "U01CA224146; U01CA224193-01; 4U01CA224348-02"
pac_list = [award.strip() for award in pac_str.split(';')]
nofo_list = []

# Gather grants from API for pacmen awards and blank nofos
award_data = get_nih_reporter_grants(pac_list,'award',True)
nofo_data = get_nih_reporter_grants(nofo_list, 'nofo',True)

# Combine into single grants awards
grants_data = award_data + nofo_data

print(f"Total records found: {len(grants_data)}")
# Out:
# award: U01CA224146 1/1): {'search_id': 'kv_-tkwWkEmIGB_LnjxPIw', 'total': 3, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/kv_-tkwWkEmIGB_LnjxPIw/projects'}}
# award: U01CA224193-01 1/1): {'search_id': 'Uiu5MSe8zkuiHURByOANcQ', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/Uiu5MSe8zkuiHURByOANcQ/projects'}}
# award: 4U01CA224348-02 1/1): {'search_id': 'Wn3PaQp4Nku7vZGTcB7gjw', 'total': 1, 'offset': 0, 'limit': 500, 'sort_field': 'FiscalYear', 'sort_order': 'desc', 'sorted_by_relevance': True, 'properties': {'URL': 'https:/reporter.nih.gov/search/Wn3PaQp4Nku7vZGTcB7gjw/projects'}}
# Total records found: 5

# %% [markdown]
# ## All the pieces look good
# Time to refactor and add to `data_preparation.py`, `clean_grants_data.py`, and `main.py`
